# %% [markdown]
# <a href="https://colab.research.google.com/github/stefkong1982/netology.ru/blob/Master/Osnovy_nejronnyh_setej/Vvedenie_v_svertochnye_NS/DZ_Kondratev_svertochnye_NS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Домашнее задание. Свёрточные сети
#
# Здесь вам предстоит построить и обучить свою первую свёрточную сеть для классификации изображений на данных CIFAR10.

# %% [markdown]
# ## Данные
#
# CIFAR10
# * 60000 RGB изображений размером 32x32x3
# * 10 классов: самолёты, собаки, рыбы и т.п.
#
# <img src="https://www.samyzaf.com/ML/cifar10/cifar1.jpg" style="width:60%">

# %% [markdown]
# Загрузите данные, разделите их на обучающую и тестовую выборки. Размер тестовой выборки должен быть $10^4$.

# %%
import numpy as np
from tensorflow.keras import layers, models, Input
from tensorflow.keras.datasets import cifar10

# Загрузка данных
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step

# %% [markdown]
# Создание валидационного и обучающего наборов

# %%
from sklearn.model_selection import train_test_split

# Создаем валидационную выборку из обучающего набора
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=42)

# Проверка размеров после разделения
print("Размер обучающего набора:", x_train.shape[0])  # Ожидаем 40,000
print("Размер валидационного набора:", x_val.shape[0])  # Ожидаем 10,000
print("Размер тестового набора:", x_test.shape[0])      # Ожидаем 10,000
# Out:
# Размер обучающего набора: 40000
# Размер валидационного набора: 10000
# Размер тестового набора: 10000

# %% [markdown]
# Прежде чем приступать к основной работе, стоит убедиться что загруженно именно то, что требовалось:

# %%
import matplotlib.pyplot as plt

# Список классов CIFAR-10
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# Функция для отображения изображений
def plot_images(images, labels, class_names, n=10):
    plt.figure(figsize=(15, 6))
    for i in range(n):
        plt.subplot(2, 5, i+1)
        plt.imshow(images[i])
        plt.title(class_names[labels[i][0]])  # labels[i][0] потому что y_train имеет форму (n, 1)
        plt.axis('off')
    plt.show()

# Отобразим первые 10 изображений из обучающего набора
plot_images(x_train, y_train, class_names)

# %% [markdown]
# ## Подготовка данных
#
# Сейчас каждый пиксель изображения закодирован тройкой чисел (RGB) __от 0 до 255__. Однако лучше себя показывает подход, где значения входов нейросети распределены недалеко от 0.
#
# Давайте приведём все данные в диапазон __`[0, 1]`__ — просто разделим на соответствующий коэффициент:

# %%
# Нормализация данных
x_train = x_train / 255
x_val = x_val / 255
x_test = x_test / 255

# %% [markdown]
# Исполните код ниже для проверки, что все выполнено корректно.

# %%
assert np.shape(x_train) == (40000, 32, 32, 3), "data shape should not change"
assert 0.9 <= max(map(np.max, (x_train, x_val, x_test))) <= 1.05
assert 0.0 <= min(map(np.min, (x_train, x_val, x_test))) <= 0.1
assert len(np.unique(x_test / 255.)) > 10, "make sure you casted data to float type"

# %% [markdown]
# ## Архитектура сети
#
# Для начала реализуйте простую нейросеть:
# 1. принимает на вход картинки размера 32 x 32 x 3;
# 2. вытягивает их в вектор (`keras.layers.Flatten`);
# 3. пропускает через 1 или 2 полносвязных слоя;
# 4. выходной слой отдает вероятности принадлежности к каждому из 10 классов.

# %% [markdown]
# Создайте полносвязную сеть:

# %%
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import EarlyStopping

# Создание модели
model = models.Sequential([
    Input(shape=(32, 32, 3)),                   # Входной слой
    layers.Flatten(),                            # Преобразование изображения в вектор
    layers.Dense(128, activation='relu'),       # Первый полносвязный слой
    layers.Dense(64, activation='relu'),        # Второй полносвязный слой
    layers.Dense(10, activation='softmax')      # Выходной слой с 10 классами
])

# Компиляция модели с использованием SGD
model.compile(optimizer='sgd',
              loss='sparse_categorical_crossentropy',
              metrics=['sparse_categorical_accuracy'])

# Вывод структуры модели
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)                    │ (None, 3072)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │         393,344 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 10)                  │             650 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 402,250 (1.53 MB)
#  Trainable params: 402,250 (1.53 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Обучение сети

# %% [markdown]
# ### **Задание 1.1 (обязательно)**
#
# Будем минимизировать многоклассовую кроссэкнропию с помощью __sgd__. Вам нужно получить сеть, которая достигнет __не менее 45%__ __accuracy__ на тестовых данных.
#
# __Важно:__
#
# поскольку в y_train лежат номера классов, Керасу нужно либо указать sparse функции потерь и метрики оценки качества классификации (`sparse_categorical_crossentropy` и `sparse_categorical_accuracy`), либо конвертировать метки в one-hot формат.
#
# ### Полезные советы
# * `model.compile` позволяет указать, какие метрики вы хотите вычислять.
# * В `model.fit` можно передать валидационную выборку (`validation_data=[X_val, y_val]`), для отслеживания прогресса на ней. Также рекомендуем сохранять результаты в [tensorboard](https://keras.io/callbacks/#tensorboard) или [wandb](https://docs.wandb.ai/integrations/jupyter). **Важно: логи tensorboard не получится без боли посмотреть через colab.** Workaround: скачать логи и запустить tensorboard локально или помучаться [с этим](https://stackoverflow.com/questions/47818822/can-i-use-tensorboard-with-google-colab).
# * По умолчанию сеть учится 1 эпоху. Совсем не факт, что вам этого хватит. Число эпох можно настроить в методе `fit` (`epochs`).
# * Ещё у Кераса есть много [полезных callback-ов](https://keras.io/callbacks/), которые можно попробовать. Например, автоматическая остановка или подбор скорости обучения.

# %%
# Создание EarlyStopping для предотвращения переобучения
early_stopping = EarlyStopping(monitor='val_sparse_categorical_accuracy', patience=5, restore_best_weights=True)

# Обучение модели
history = model.fit(x_train, y_train,
                    validation_data=(x_val, y_val),
                    epochs=10,  # Настройка количества эпох
                    batch_size=32,  # Размер батча
                    callbacks=[early_stopping],
                    verbose=1)  # Вывод результатов обучения
# Out:
# Epoch 1/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 9ms/step - loss: 2.0291 - sparse_categorical_accuracy: 0.2578 - val_loss: 1.7802 - val_sparse_categorical_accuracy: 0.3713
# Epoch 2/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - loss: 1.7579 - sparse_categorical_accuracy: 0.3797 - val_loss: 1.7111 - val_sparse_categorical_accuracy: 0.3941
# Epoch 3/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - loss: 1.6742 - sparse_categorical_accuracy: 0.4080 - val_loss: 1.6385 - val_sparse_categorical_accuracy: 0.4092
# Epoch 4/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 11s 7ms/step - loss: 1.6233 - sparse_categorical_accuracy: 0.4263 - val_loss: 1.6441 - val_sparse_categorical_accuracy: 0.4130
# Epoch 5/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 1.5802 - sparse_categorical_accuracy: 0.4434 - val_loss: 1.5825 - val_sparse_categorical_accuracy: 0.4341
# Epoch 6/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 1.5428 - sparse_categorical_accuracy: 0.4551 - val_loss: 1.5968 - val_sparse_categorical_accuracy: 0.4333
# Epoch 7/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 1.5238 - sparse_categorical_accuracy: 0.4613 - val_loss: 1.5821 - val_sparse_categorical_accuracy: 0.4484
# Epoch 8/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 1.4848 - sparse_categorical_accuracy: 0.4735 - val_loss: 1.5426 - val_sparse_categorical_accuracy: 0.4499
# Epoch 9/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 1.4619 - sparse_categorical_accuracy: 0.4833 - val_loss: 1.4915 - val_sparse_categorical_accuracy: 0.4694
# Epoch 10/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 1.4406 - sparse_categorical_accuracy: 0.4937 - val_loss: 1.5013 - val_sparse_categorical_accuracy: 0.4716

# %% [markdown]
# А теперь можно проверить качество вашей сети, выполнив код ниже:

# %%
import pandas as pd

# Создаем DataFrame где будут копиться результаты оценок моделей
results_df = pd.DataFrame(columns=['Model Name', 'Test Loss', 'Test Accuracy'])

# %%
# Оценка модели на тестовом наборе
test_loss, test_accuracy = model.evaluate(x_test, y_test)

# Параметры для настройки вашей модели
model_name = "MyModel1"  # Уникальное имя для текущей модели

# Используем .loc для добавления данных в существующий DataFrame
results_df.loc[0] = [model_name, test_loss, test_accuracy]
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.4905 - sparse_categorical_accuracy: 0.4670

# %%
# Выводим финальную таблицу с результатами
print(results_df)
# Out:
#   Model Name  Test Loss  Test Accuracy
# 0   MyModel1   1.489534         0.4685

# %% [markdown]
# Это означает, что модель которая достигнет не менее 45% accuracy на тестовых данных.

# %% [markdown]
# ## Карманная сверточная сеть

# %% [markdown]
# ### **Задание 1.2 (обязательно)**
#
# Реализуйте небольшую свёрточную сеть. Совсем небольшую:
# 1. Входной слой
# 2. Свёртка 3x3 с 10 фильтрами
# 3. Нелинейность на ваш вкус
# 4. Max-pooling 2x2
# 5. Вытягиваем оставшееся в вектор (Flatten)
# 6. Полносвязный слой на 100 нейронов
# 7. Нелинейность на ваш вкус
# 8. Выходной полносвязный слой с softmax
#
# Обучите её так же, как и предыдущую сеть. Если всё хорошо, у вас получится accuracy не меньше __50%__.

# %% [markdown]
# Реализация модели

# %%
import pandas as pd
from tensorflow.keras import models, layers
from tensorflow.keras.callbacks import EarlyStopping

# Создание модели сверточной нейронной сети с использованием Input
cnn_model = models.Sequential()

# Входной слой
cnn_model.add(layers.Input(shape=(32, 32, 3)))  # Явное определение входных данных

# Слой свёртки
cnn_model.add(layers.Conv2D(10, (3, 3), activation='relu'))  # Свёртка 3x3 с 10 фильтрами
cnn_model.add(layers.MaxPooling2D(pool_size=(2, 2)))  # Max-pooling 2x2

# Преобразование в вектор
cnn_model.add(layers.Flatten())

# Полносвязный слой
cnn_model.add(layers.Dense(100, activation='relu'))  # Полносвязный слой на 100 нейронов

# Выходной слой
cnn_model.add(layers.Dense(10, activation='softmax'))  # Выходной слой с softmax

# Компиляция модели
cnn_model.compile(optimizer='sgd',
                  loss='sparse_categorical_crossentropy',
                  metrics=['sparse_categorical_accuracy'])

# Вывод структуры модели
cnn_model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 30, 30, 10)          │             280 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 15, 15, 10)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 2250)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 100)                 │         225,100 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 10)                  │           1,010 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 226,390 (884.34 KB)
#  Trainable params: 226,390 (884.34 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Обучение

# %%
# Создание EarlyStopping для предотвращения переобучения
early_stopping = EarlyStopping(monitor='val_sparse_categorical_accuracy', patience=5, restore_best_weights=True)

# Обучение модели
history = cnn_model.fit(x_train, y_train,
                        validation_data=(x_val, y_val),
                        epochs=10,  # Настройка количества эпох
                        batch_size=32,  # Размер батча
                        callbacks=[early_stopping],
                        verbose=1)  # Вывод результатов обучения
# Out:
# Epoch 1/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 2.0876 - sparse_categorical_accuracy: 0.2425 - val_loss: 1.8182 - val_sparse_categorical_accuracy: 0.3593
# Epoch 2/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 1.7679 - sparse_categorical_accuracy: 0.3779 - val_loss: 1.6334 - val_sparse_categorical_accuracy: 0.4351
# Epoch 3/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 39s 19ms/step - loss: 1.6140 - sparse_categorical_accuracy: 0.4352 - val_loss: 1.5630 - val_sparse_categorical_accuracy: 0.4508
# Epoch 4/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 21s 17ms/step - loss: 1.4815 - sparse_categorical_accuracy: 0.4780 - val_loss: 1.4405 - val_sparse_categorical_accuracy: 0.4795
# Epoch 5/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 42s 18ms/step - loss: 1.3832 - sparse_categorical_accuracy: 0.5073 - val_loss: 1.3636 - val_sparse_categorical_accuracy: 0.5144
# Epoch 6/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 23s 18ms/step - loss: 1.3221 - sparse_categorical_accuracy: 0.5331 - val_loss: 1.2992 - val_sparse_categorical_accuracy: 0.5386
# Epoch 7/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 23s 19ms/step - loss: 1.2533 - sparse_categorical_accuracy: 0.5611 - val_loss: 1.2889 - val_sparse_categorical_accuracy: 0.5427
# Epoch 8/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 41s 19ms/step - loss: 1.2116 - sparse_categorical_accuracy: 0.5736 - val_loss: 1.2616 - val_sparse_categorical_accuracy: 0.5531
# Epoch 9/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 22s 18ms/step - loss: 1.1671 - sparse_categorical_accuracy: 0.5907 - val_loss: 1.2412 - val_sparse_categorical_accuracy: 0.5653
# Epoch 10/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 23s 18ms/step - loss: 1.1367 - sparse_categorical_accuracy: 0.6024 - val_loss: 1.2233 - val_sparse_categorical_accuracy: 0.5732

# %% [markdown]
# Давайте посмотрим, смогла ли карманная сверточная сеть побить заданный порог по качеству:

# %%
# Оценка модели на тестовом наборе
test_loss, test_accuracy = cnn_model.evaluate(x_test, y_test)

# Параметры для настройки вашей модели
model_name = "CNN_Model1"  # Уникальное имя для текущей модели

# Добавляем результаты тестирования в DataFrame
results_df.loc[1] = [model_name, test_loss, test_accuracy]
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 1.2115 - sparse_categorical_accuracy: 0.5749

# %%
# Выводим финальную таблицу с результатами
print(results_df)
# Out:
#    Model Name  Test Loss  Test Accuracy
# 0    MyModel1   1.489534         0.4685
# 1  CNN_Model1   1.218909         0.5696

# %% [markdown]
# Согласно результатам оценки модели на тестовых данных, карманная свёрточная сеть достигла точности, которая превышает заданный порог в 50%. Это является положительным результатом, так как модель смогла успешно классифицировать более половины тестовых изображений правильно. Это подтверждает, что даже простая архитектура свёрточной сети способна извлекать значительную информацию из изображений и выполнять задачу классификации.

# %% [markdown]
# ## Учимся учить
#
# А теперь научимся сравнивать кривые обучения моделей — зависимости значения accuracy от количества итераций.
#
# Вам потребуется реализовать _экспериментальный стенд_ — вспомогательный код, в который вы сможете подать несколько архитектур и методов обучения, чтобы он их обучил и вывел графики кривых обучения. Это можно сделать с помощью `keras.callbacks` — `TensorBoard` или `History`.
#
# Будьте морально готовы, что на обучение уйдёт _много времени_. Даже если вы ограничитесь 10 эпохами. Пока идёт обучение, вы можете переключиться на другие задания или заняться чем-нибудь приятным: поспать, например.

# %% [markdown]
# Реализация

# %%
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras import models, layers
from tensorflow.keras.callbacks import EarlyStopping

# Функция для обучения модели
def train_model(model, x_train, y_train, x_val, y_val, epochs=10, batch_size=32):
    early_stopping = EarlyStopping(monitor='val_sparse_categorical_accuracy', patience=5, restore_best_weights=True)
    history = model.fit(x_train, y_train,
                        validation_data=(x_val, y_val),
                        epochs=epochs,
                        batch_size=batch_size,
                        callbacks=[early_stopping],
                        verbose=1)
    return history

# Функция для визуализации кривых обучения
def plot_learning_curves(history, model_name):
    plt.figure(figsize=(12, 4))

    # Accuracy
    plt.subplot(1, 2, 1)
    plt.plot(history.history['sparse_categorical_accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_sparse_categorical_accuracy'], label='Validation Accuracy')
    plt.title(f'{model_name} Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    # Loss
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title(f'{model_name} Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.show()

# Определим модели

# 1. Полносвязная модель
def create_dense_model():
    model = models.Sequential([
        layers.Input(shape=(32, 32, 3)),
        layers.Flatten(),
        layers.Dense(128, activation='relu'),
        layers.Dense(64, activation='relu'),
        layers.Dense(10, activation='softmax')
    ])
    model.compile(optimizer='sgd',
                  loss='sparse_categorical_crossentropy',
                  metrics=['sparse_categorical_accuracy'])
    return model

# 2. Карманная сверточная модель
def create_cnn_model():
    model = models.Sequential([
        layers.Input(shape=(32, 32, 3)),
        layers.Conv2D(10, (3, 3), activation='relu'),
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Flatten(),
        layers.Dense(100, activation='relu'),
        layers.Dense(10, activation='softmax')
    ])
    model.compile(optimizer='sgd',
                  loss='sparse_categorical_crossentropy',
                  metrics=['sparse_categorical_accuracy'])
    return model

# %%
# Обучение моделей
models_to_train = [create_dense_model, create_cnn_model]
model_names = ["Dense Model", "CNN Model"]

# %%
# извлечение результатов
for create_model, model_name in zip(models_to_train, model_names):
    model = create_model()
    history = train_model(model, x_train, y_train, x_val, y_val, epochs=10)

    # Оценка модели и добавление результатов в DataFrame
    test_loss, test_accuracy = model.evaluate(x_test, y_test)
    results_df.loc[len(results_df)] = [model_name, test_loss, test_accuracy]

    # Построение кривых обучения
    plot_learning_curves(history, model_name)
# Out:
# Epoch 1/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - loss: 2.0691 - sparse_categorical_accuracy: 0.2449 - val_loss: 1.7923 - val_sparse_categorical_accuracy: 0.3711
# Epoch 2/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - loss: 1.7852 - sparse_categorical_accuracy: 0.3673 - val_loss: 1.7393 - val_sparse_categorical_accuracy: 0.3818
# Epoch 3/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 1.6893 - sparse_categorical_accuracy: 0.4051 - val_loss: 1.6571 - val_sparse_categorical_accuracy: 0.4090
# Epoch 4/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 1.6290 - sparse_categorical_accuracy: 0.4227 - val_loss: 1.5936 - val_sparse_categorical_accuracy: 0.4319
# Epoch 5/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 1.5880 - sparse_categorical_accuracy: 0.4376 - val_loss: 1.5930 - val_sparse_categorical_accuracy: 0.4207
# Epoch 6/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 1.5448 - sparse_categorical_accuracy: 0.4563 - val_loss: 1.5681 - val_sparse_categorical_accuracy: 0.4349
# Epoch 7/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 7ms/step - loss: 1.5192 - sparse_categorical_accuracy: 0.4659 - val_loss: 1.5387 - val_sparse_categorical_accuracy: 0.4490
# Epoch 8/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 1.4913 - sparse_categorical_accuracy: 0.4698 - val_loss: 1.5287 - val_sparse_categorical_accuracy: 0.4562
# Epoch 9/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 1.4720 - sparse_categorical_accuracy: 0.4788 - val_loss: 1.5089 - val_sparse_categorical_accuracy: 0.4640
# Epoch 10/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 1.4429 - sparse_categorical_accuracy: 0.4907 - val_loss: 1.5274 - val_sparse_categorical_accuracy: 0.4543
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.4918 - sparse_categorical_accuracy: 0.4717
# Epoch 1/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 25s 19ms/step - loss: 2.1008 - sparse_categorical_accuracy: 0.2283 - val_loss: 1.7895 - val_sparse_categorical_accuracy: 0.3675
# Epoch 2/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 41s 19ms/step - loss: 1.7506 - sparse_categorical_accuracy: 0.3865 - val_loss: 1.6288 - val_sparse_categorical_accuracy: 0.4233
# Epoch 3/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - loss: 1.5958 - sparse_categorical_accuracy: 0.4364 - val_loss: 1.5065 - val_sparse_categorical_accuracy: 0.4686
# Epoch 4/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 41s 19ms/step - loss: 1.4547 - sparse_categorical_accuracy: 0.4858 - val_loss: 1.4193 - val_sparse_categorical_accuracy: 0.4949
# Epoch 5/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 41s 19ms/step - loss: 1.3620 - sparse_categorical_accuracy: 0.5212 - val_loss: 1.3414 - val_sparse_categorical_accuracy: 0.5242
# Epoch 6/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 41s 19ms/step - loss: 1.2923 - sparse_categorical_accuracy: 0.5433 - val_loss: 1.3180 - val_sparse_categorical_accuracy: 0.5327
# Epoch 7/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 22s 18ms/step - loss: 1.2468 - sparse_categorical_accuracy: 0.5595 - val_loss: 1.3027 - val_sparse_categorical_accuracy: 0.5474
# Epoch 8/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 42s 19ms/step - loss: 1.2007 - sparse_categorical_accuracy: 0.5769 - val_loss: 1.3114 - val_sparse_categorical_accuracy: 0.5373
# Epoch 9/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 22s 18ms/step - loss: 1.1744 - sparse_categorical_accuracy: 0.5885 - val_loss: 1.2264 - val_sparse_categorical_accuracy: 0.5686
# Epoch 10/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 23s 19ms/step - loss: 1.1352 - sparse_categorical_accuracy: 0.6043 - val_loss: 1.2382 - val_sparse_categorical_accuracy: 0.5629
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 1.2157 - sparse_categorical_accuracy: 0.5695

# %%
# Вывод результатов
print(results_df)
# Out:
#     Model Name  Test Loss  Test Accuracy
# 0     MyModel1   1.489534         0.4685
# 1   CNN_Model1   1.218909         0.5696
# 2  Dense Model   1.492900         0.4700
# 3    CNN Model   1.228506         0.5598

# %% [markdown]
#   - Свёрточные модели продемонстрировали значительно более высокую точность на тестовых данных по сравнению с полносвязными моделями. Это явление является довольно распространённым, поскольку свёрточные сети (CNNs) более эффективны в захвате пространственных иерархий и особенностей в изображениях благодаря применению свёрточных слоёв и подвыборки.
#   - Обе свёрточные сети достигли значений точности выше 50%, что существенно выше минимальных требований, определённых в задании.

# %% [markdown]
# ### **Задание 1.3 (опционально)**
#
# Попробуйте использовать различные методы оптимизации (sgd, momentum, adam) с параметрами по умолчанию. Какой из методов работает лучше?

# %% [markdown]
# Для удобства напишем класс Evaluator, который принимает в себя дикты виды {имя_оптимайзера: инстанс}, {имя модели: инстанс} и обучает всевозможные комбинации моделей с оптимайзерами при помощи метода fit (попутно записывая логи отдельно для каждой модели). Также пригодится метод evaluate для отображения итоговых скоров.

# %% [markdown]
# Пользоваться классом не обязательно. По умолчанию класс использует tensorboard. Если вы выше использовали wandb -- советуем дописать callback.

# %%
import pandas as pd
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import EarlyStopping

class Evaluator:
    def __init__(self, models, optimizers, x_train, y_train, x_val, y_val, x_test, y_test, epochs=10, batch_size=32):
        self.models = models  # {'model_name': model_instance}
        self.optimizers = optimizers  # {'optimizer_name': optimizer_instance}
        self.x_train = x_train
        self.y_train = y_train
        self.x_val = x_val
        self.y_val = y_val
        self.x_test = x_test
        self.y_test = y_test
        self.epochs = epochs
        self.batch_size = batch_size

    def train_and_evaluate(self):
        global results_df  # Используем глобальный DataFrame для объединения
        new_results = []  # Список для хранения новых результатов

        for model_name, model in self.models.items():
            for optimizer_name, optimizer_class in self.optimizers.items():
                # Создаем новый экземпляр модели
                temp_model = model()

                # Создаем новый экземпляр оптимизатора (каждый раз)
                optimizer = optimizer_class if isinstance(optimizer_class, type) else optimizer_class.__class__

                # Компилируем модель с текущим оптимизатором
                temp_model.compile(optimizer=optimizer(),
                                  loss='sparse_categorical_crossentropy',
                                  metrics=['sparse_categorical_accuracy'])

                # Обучаем модель с использованием ранней остановки
                early_stopping = EarlyStopping(monitor='val_sparse_categorical_accuracy', patience=5, restore_best_weights=True)

                history = temp_model.fit(
                    self.x_train, self.y_train,
                    validation_data=(self.x_val, self.y_val),
                    epochs=self.epochs,
                    batch_size=self.batch_size,
                    callbacks=[early_stopping],
                    verbose=1
                )

                # Оценка модели на тестовом наборе
                test_loss, test_accuracy = temp_model.evaluate(self.x_test, self.y_test, verbose=0)

                # Добавляем новые результаты в список
                new_results.append({
                    'Model Name': model_name,
                    'Optimizer': optimizer_name,
                    'Test Loss': test_loss,
                    'Test Accuracy': test_accuracy
                })

        # Создаем временный DataFrame для новых результатов
        new_results_df = pd.DataFrame(new_results)

        # Объединяем новые результаты с существующими
        results_df = pd.concat([results_df, new_results_df], ignore_index=True)

    def display_results(self):
        # Вывод результатов
        print(results_df)

# Пример определения моделей и оптимизаторов
models_dict = {
    "Dense Model": create_dense_model,
    "CNN Model": create_cnn_model
}

optimizers_dict = {
    "SGD": optimizers.SGD(),
    "Momentum": optimizers.SGD(momentum=0.9),
    "Adam": optimizers.Adam()
}

# Создание объекта Evaluator и обучение
evaluator = Evaluator(models_dict, optimizers_dict, x_train, y_train, x_val, y_val, x_test, y_test, epochs=10)
evaluator.train_and_evaluate()
# Out:
# Epoch 1/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 2.0523 - sparse_categorical_accuracy: 0.2526 - val_loss: 1.8973 - val_sparse_categorical_accuracy: 0.3240
# Epoch 2/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 1.7809 - sparse_categorical_accuracy: 0.3686 - val_loss: 1.7065 - val_sparse_categorical_accuracy: 0.3878
# Epoch 3/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - loss: 1.6873 - sparse_categorical_accuracy: 0.4017 - val_loss: 1.6869 - val_sparse_categorical_accuracy: 0.3991
# Epoch 4/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 1.6335 - sparse_categorical_accuracy: 0.4207 - val_loss: 1.6261 - val_sparse_categorical_accuracy: 0.4242
# Epoch 5/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 1.5824 - sparse_categorical_accuracy: 0.4384 - val_loss: 1.6222 - val_sparse_categorical_accuracy: 0.4234
# Epoch 6/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 1.5363 - sparse_categorical_accuracy: 0.4565 - val_loss: 1.5596 - val_sparse_categorical_accuracy: 0.4472
# Epoch 7/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 1.5177 - sparse_categorical_accuracy: 0.4610 - val_loss: 1.5988 - val_sparse_categorical_accuracy: 0.4239
# Epoch 8/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 1.4863 - sparse_categorical_accuracy: 0.4747 - val_loss: 1.5563 - val_sparse_categorical_accuracy: 0.4449
# Epoch 9/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 1.4615 - sparse_categorical_accuracy: 0.4798 - val_loss: 1.5518 - val_sparse_categorical_accuracy: 0.4485
# Epoch 10/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 1.4490 - sparse_categorical_accuracy: 0.4892 - val_loss: 1.4900 - val_sparse_categorical_accuracy: 0.4731
# Epoch 1/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 2.0575 - sparse_categorical_accuracy: 0.2476 - val_loss: 1.8027 - val_sparse_categorical_accuracy: 0.3568
# Epoch 2/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 1.7695 - sparse_categorical_accuracy: 0.3690 - val_loss: 1.7260 - val_sparse_categorical_accuracy: 0.3963
# Epoch 3/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 1.6885 - sparse_categorical_accuracy: 0.4035 - val_loss: 1.6706 - val_sparse_categorical_accuracy: 0.4009
# Epoch 4/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 1.6294 - sparse_categorical_accuracy: 0.4248 - val_loss: 1.6180 - val_sparse_categorical_accuracy: 0.4197
# Epoch 5/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 1.5938 - sparse_categorical_accuracy: 0.4383 - val_loss: 1.6111 - val_sparse_categorical_accuracy: 0.4207
# Epoch 6/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 1.5468 - sparse_categorical_accuracy: 0.4546 - val_loss: 1.5543 - val_sparse_categorical_accuracy: 0.4485
# Epoch 7/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 1.5127 - sparse_categorical_accuracy: 0.4650 - val_loss: 1.6130 - val_sparse_categorical_accuracy: 0.4236
# Epoch 8/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 1.4924 - sparse_categorical_accuracy: 0.4740 - val_loss: 1.5385 - val_sparse_categorical_accuracy: 0.4483
# Epoch 9/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 1.4668 - sparse_categorical_accuracy: 0.4821 - val_loss: 1.5267 - val_sparse_categorical_accuracy: 0.4592
# Epoch 10/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - loss: 1.4413 - sparse_categorical_accuracy: 0.4880 - val_loss: 1.5235 - val_sparse_categorical_accuracy: 0.4547
# Epoch 1/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 12s 8ms/step - loss: 2.0433 - sparse_categorical_accuracy: 0.2642 - val_loss: 1.8134 - val_sparse_categorical_accuracy: 0.3372
# Epoch 2/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - loss: 1.7564 - sparse_categorical_accuracy: 0.3695 - val_loss: 1.7420 - val_sparse_categorical_accuracy: 0.3773
# Epoch 3/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - loss: 1.6901 - sparse_categorical_accuracy: 0.3968 - val_loss: 1.6777 - val_sparse_categorical_accuracy: 0.3941
# Epoch 4/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 19s 7ms/step - loss: 1.6287 - sparse_categorical_accuracy: 0.4175 - val_loss: 1.6568 - val_sparse_categorical_accuracy: 0.4034
# Epoch 5/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 13s 9ms/step - loss: 1.5954 - sparse_categorical_accuracy: 0.4301 - val_loss: 1.6014 - val_sparse_categorical_accuracy: 0.4254
# Epoch 6/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 1.5637 - sparse_categorical_accuracy: 0.4421 - val_loss: 1.5906 - val_sparse_categorical_accuracy: 0.4358
# Epoch 7/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 1.5372 - sparse_categorical_accuracy: 0.4513 - val_loss: 1.5681 - val_sparse_categorical_accuracy: 0.4347
# Epoch 8/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - loss: 1.5199 - sparse_categorical_accuracy: 0.4589 - val_loss: 1.5587 - val_sparse_categorical_accuracy: 0.4427
# Epoch 9/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 1.4964 - sparse_categorical_accuracy: 0.4640 - val_loss: 1.5640 - val_sparse_categorical_accuracy: 0.4398
# Epoch 10/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 1.4877 - sparse_categorical_accuracy: 0.4673 - val_loss: 1.5729 - val_sparse_categorical_accuracy: 0.4369
# Epoch 1/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - loss: 2.1139 - sparse_categorical_accuracy: 0.2147 - val_loss: 1.8259 - val_sparse_categorical_accuracy: 0.3524
# Epoch 2/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 42s 20ms/step - loss: 1.7444 - sparse_categorical_accuracy: 0.3860 - val_loss: 1.5692 - val_sparse_categorical_accuracy: 0.4431
# Epoch 3/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 39s 19ms/step - loss: 1.5653 - sparse_categorical_accuracy: 0.4456 - val_loss: 1.4729 - val_sparse_categorical_accuracy: 0.4726
# Epoch 4/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 22s 17ms/step - loss: 1.4767 - sparse_categorical_accuracy: 0.4768 - val_loss: 1.4210 - val_sparse_categorical_accuracy: 0.4973
# Epoch 5/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 43s 19ms/step - loss: 1.4069 - sparse_categorical_accuracy: 0.5030 - val_loss: 1.3745 - val_sparse_categorical_accuracy: 0.5153
# Epoch 6/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 43s 20ms/step - loss: 1.3415 - sparse_categorical_accuracy: 0.5249 - val_loss: 1.3319 - val_sparse_categorical_accuracy: 0.5300
# Epoch 7/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 22s 17ms/step - loss: 1.2756 - sparse_categorical_accuracy: 0.5534 - val_loss: 1.3749 - val_sparse_categorical_accuracy: 0.5145
# Epoch 8/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 44s 20ms/step - loss: 1.2211 - sparse_categorical_accuracy: 0.5696 - val_loss: 1.2540 - val_sparse_categorical_accuracy: 0.5601
# Epoch 9/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 22s 18ms/step - loss: 1.1735 - sparse_categorical_accuracy: 0.5887 - val_loss: 1.2494 - val_sparse_categorical_accuracy: 0.5610
# Epoch 10/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 21ms/step - loss: 1.1433 - sparse_categorical_accuracy: 0.5986 - val_loss: 1.2154 - val_sparse_categorical_accuracy: 0.5756
# Epoch 1/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 20ms/step - loss: 2.0820 - sparse_categorical_accuracy: 0.2376 - val_loss: 1.7562 - val_sparse_categorical_accuracy: 0.3740
# Epoch 2/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - loss: 1.7046 - sparse_categorical_accuracy: 0.3982 - val_loss: 1.5552 - val_sparse_categorical_accuracy: 0.4423
# Epoch 3/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 41s 19ms/step - loss: 1.5394 - sparse_categorical_accuracy: 0.4516 - val_loss: 1.4751 - val_sparse_categorical_accuracy: 0.4701
# Epoch 4/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 40s 19ms/step - loss: 1.4445 - sparse_categorical_accuracy: 0.4895 - val_loss: 1.4776 - val_sparse_categorical_accuracy: 0.4817
# Epoch 5/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 40s 18ms/step - loss: 1.3617 - sparse_categorical_accuracy: 0.5170 - val_loss: 1.3413 - val_sparse_categorical_accuracy: 0.5241
# Epoch 6/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 24s 19ms/step - loss: 1.3059 - sparse_categorical_accuracy: 0.5399 - val_loss: 1.3044 - val_sparse_categorical_accuracy: 0.5393
# Epoch 7/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 27s 22ms/step - loss: 1.2474 - sparse_categorical_accuracy: 0.5620 - val_loss: 1.2768 - val_sparse_categorical_accuracy: 0.5434
# Epoch 8/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 23s 18ms/step - loss: 1.1929 - sparse_categorical_accuracy: 0.5787 - val_loss: 1.2464 - val_sparse_categorical_accuracy: 0.5584
# Epoch 9/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 42s 19ms/step - loss: 1.1642 - sparse_categorical_accuracy: 0.5894 - val_loss: 1.2493 - val_sparse_categorical_accuracy: 0.5643
# Epoch 10/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 23s 18ms/step - loss: 1.1181 - sparse_categorical_accuracy: 0.6052 - val_loss: 1.2152 - val_sparse_categorical_accuracy: 0.5745
# Epoch 1/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 28s 22ms/step - loss: 1.7356 - sparse_categorical_accuracy: 0.3735 - val_loss: 1.3383 - val_sparse_categorical_accuracy: 0.5297
# Epoch 2/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 39s 20ms/step - loss: 1.2868 - sparse_categorical_accuracy: 0.5475 - val_loss: 1.2512 - val_sparse_categorical_accuracy: 0.5515
# Epoch 3/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 41s 20ms/step - loss: 1.1553 - sparse_categorical_accuracy: 0.5887 - val_loss: 1.1875 - val_sparse_categorical_accuracy: 0.5819
# Epoch 4/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 44s 23ms/step - loss: 1.0736 - sparse_categorical_accuracy: 0.6226 - val_loss: 1.1913 - val_sparse_categorical_accuracy: 0.5807
# Epoch 5/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 1.0221 - sparse_categorical_accuracy: 0.6426 - val_loss: 1.1693 - val_sparse_categorical_accuracy: 0.5948
# Epoch 6/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 42s 21ms/step - loss: 0.9721 - sparse_categorical_accuracy: 0.6571 - val_loss: 1.1578 - val_sparse_categorical_accuracy: 0.6033
# Epoch 7/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 40s 20ms/step - loss: 0.9203 - sparse_categorical_accuracy: 0.6802 - val_loss: 1.1710 - val_sparse_categorical_accuracy: 0.5984
# Epoch 8/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 25s 20ms/step - loss: 0.8769 - sparse_categorical_accuracy: 0.6938 - val_loss: 1.1445 - val_sparse_categorical_accuracy: 0.6120
# Epoch 9/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 48s 26ms/step - loss: 0.8299 - sparse_categorical_accuracy: 0.7104 - val_loss: 1.1767 - val_sparse_categorical_accuracy: 0.6083
# Epoch 10/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 34s 20ms/step - loss: 0.7816 - sparse_categorical_accuracy: 0.7281 - val_loss: 1.1857 - val_sparse_categorical_accuracy: 0.6062

# %%
# Вывод результатов
print(results_df)
# Out:
#     Model Name  Test Loss  Test Accuracy Optimizer
# 0     MyModel1   1.489534         0.4685       NaN
# 1   CNN_Model1   1.218909         0.5696       NaN
# 2  Dense Model   1.492900         0.4700       NaN
# 3    CNN Model   1.228506         0.5598       NaN
# 4  Dense Model   1.477738         0.4761       SGD
# 5  Dense Model   1.512902         0.4616  Momentum
# 6  Dense Model   1.538135         0.4509      Adam
# 7    CNN Model   1.211614         0.5711       SGD
# 8    CNN Model   1.212484         0.5689  Momentum
# 9    CNN Model   1.154503         0.6054      Adam

# %% [markdown]
# Прокомментируйте полученные результаты.

# %% [markdown]
# Эффективность оптимизаторов
# - Сравнение между оптимизаторами:
#   - SGD: Для обоих типов моделей SGD показал вполне конкурентные результаты, особенно для свёрточной модели, где точность составила 0.5711, что уже явно выше 50%.
#   - Momentum: Использование момента не дало значительного улучшения по сравнению с простым SGD. Результаты очень близки и не показали заметной выгоды от использования момента.
#   - Adam: Этот адаптивный оптимизатор, как правило, считается одним из лучших для различных задач глубокого обучения. Действительно, он показал наилучшие результаты среди всех примененных оптимизаторов для CNN, достигнув точности 0.6054. Однако для Dense модели он не смог показать лучшие результаты, даже хуже чем SGD.

# %% [markdown]
# **Задание 1.4 (опционально)** Добавьте нормализацию по батчу (`BatchNormalization`) между свёрткой и активацией. Попробуйте использовать несколько нормализаций — в свёрточных и полносвязных слоях.

# %% [markdown]
# Для удобства реализуем класс Models, который по сути будет являться списком моделей с двумя методами: add (добавить слой ко всем моделям) и add_create (создать новую модель на основе базовой с дополнительным слоем). Пользоваться им необязательно, но вдруг :)

# %%
class Models:
    def __init__(self):
        self.models = []

    def add(self, layer):
        for model in self.models:
            model.add(layer)

    def add_create(self, create_model_function, layer):
        # Создайте новую модель
        new_model = create_model_function()
        new_model.add(layer)
        self.models.append(new_model)

# %%
from tensorflow.keras import layers

def create_dense_model_with_bn():
    model = models.Sequential([
        layers.Input(shape=(32, 32, 3)),
        layers.Flatten(),
        layers.Dense(128, activation='relu'),
        layers.BatchNormalization(),  # Нормализация по батчу
        layers.Dense(64, activation='relu'),
        layers.BatchNormalization(),  # Нормализация по батчу
        layers.Dense(10, activation='softmax')
    ])
    model.compile(optimizer='sgd',
                  loss='sparse_categorical_crossentropy',
                  metrics=['sparse_categorical_accuracy'])
    return model

# %%
def create_cnn_model_with_bn():
    model = models.Sequential([
        layers.Input(shape=(32, 32, 3)),
        layers.Conv2D(10, (3, 3), activation='relu'),
        layers.BatchNormalization(),  # Нормализация по батчу
        layers.MaxPooling2D(pool_size=(2, 2)),
        layers.Flatten(),
        layers.Dense(100, activation='relu'),
        layers.BatchNormalization(),  # Нормализация по батчу
        layers.Dense(10, activation='softmax')
    ])
    model.compile(optimizer='sgd',
                  loss='sparse_categorical_crossentropy',
                  metrics=['sparse_categorical_accuracy'])
    return model

# %%
import pandas as pd

# Создаем DataFrame для хранения результатов
r_df = pd.DataFrame(columns=['Model Name', 'Test Loss', 'Test Accuracy'])

# %%
# Словарь с моделями
models_dict_with_bn = {
    "Dense Model with BN": create_dense_model_with_bn,
    "CNN Model with BN": create_cnn_model_with_bn
}

# Обучение и оценка моделей с нормализацией
for model_name, model_creator in models_dict_with_bn.items():
    model = model_creator()
    history = train_model(model, x_train, y_train, x_val, y_val, epochs=10)
    test_loss, test_accuracy = model.evaluate(x_test, y_test)
    r_df.loc[len(r_df)] = [model_name, test_loss, test_accuracy]

# Выводим результаты
print(r_df)
# Out:
# Epoch 1/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 1.9575 - sparse_categorical_accuracy: 0.3116 - val_loss: 1.7293 - val_sparse_categorical_accuracy: 0.3815
# Epoch 2/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - loss: 1.6537 - sparse_categorical_accuracy: 0.4169 - val_loss: 1.6826 - val_sparse_categorical_accuracy: 0.4066
# Epoch 3/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 1.5745 - sparse_categorical_accuracy: 0.4455 - val_loss: 1.7008 - val_sparse_categorical_accuracy: 0.3894
# Epoch 4/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 1.5425 - sparse_categorical_accuracy: 0.4558 - val_loss: 1.7403 - val_sparse_categorical_accuracy: 0.3821
# Epoch 5/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 1.5132 - sparse_categorical_accuracy: 0.4628 - val_loss: 1.6089 - val_sparse_categorical_accuracy: 0.4314
# Epoch 6/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - loss: 1.4832 - sparse_categorical_accuracy: 0.4779 - val_loss: 1.5585 - val_sparse_categorical_accuracy: 0.4503
# Epoch 7/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 1.4686 - sparse_categorical_accuracy: 0.4788 - val_loss: 1.6458 - val_sparse_categorical_accuracy: 0.4348
# Epoch 8/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 1.4432 - sparse_categorical_accuracy: 0.4846 - val_loss: 1.5596 - val_sparse_categorical_accuracy: 0.4450
# Epoch 9/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - loss: 1.4388 - sparse_categorical_accuracy: 0.4942 - val_loss: 1.6469 - val_sparse_categorical_accuracy: 0.4318
# Epoch 10/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 1.4161 - sparse_categorical_accuracy: 0.4996 - val_loss: 1.6925 - val_sparse_categorical_accuracy: 0.4096
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.5498 - sparse_categorical_accuracy: 0.4521
# Epoch 1/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 35s 27ms/step - loss: 1.8906 - sparse_categorical_accuracy: 0.3424 - val_loss: 1.4879 - val_sparse_categorical_accuracy: 0.4774
# Epoch 2/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 38s 25ms/step - loss: 1.4343 - sparse_categorical_accuracy: 0.4959 - val_loss: 1.4526 - val_sparse_categorical_accuracy: 0.4888
# Epoch 3/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 42s 26ms/step - loss: 1.3453 - sparse_categorical_accuracy: 0.5268 - val_loss: 1.3769 - val_sparse_categorical_accuracy: 0.5167
# Epoch 4/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 45s 29ms/step - loss: 1.2633 - sparse_categorical_accuracy: 0.5625 - val_loss: 1.5032 - val_sparse_categorical_accuracy: 0.4838
# Epoch 5/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 40s 28ms/step - loss: 1.2035 - sparse_categorical_accuracy: 0.5814 - val_loss: 1.3703 - val_sparse_categorical_accuracy: 0.5189
# Epoch 6/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 39s 26ms/step - loss: 1.1595 - sparse_categorical_accuracy: 0.5966 - val_loss: 1.2625 - val_sparse_categorical_accuracy: 0.5558
# Epoch 7/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 34s 27ms/step - loss: 1.0975 - sparse_categorical_accuracy: 0.6213 - val_loss: 1.2811 - val_sparse_categorical_accuracy: 0.5525
# Epoch 8/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 38s 30ms/step - loss: 1.0534 - sparse_categorical_accuracy: 0.6333 - val_loss: 1.2555 - val_sparse_categorical_accuracy: 0.5692
# Epoch 9/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 36s 27ms/step - loss: 1.0225 - sparse_categorical_accuracy: 0.6455 - val_loss: 1.2438 - val_sparse_categorical_accuracy: 0.5718
# Epoch 10/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 32s 26ms/step - loss: 0.9832 - sparse_categorical_accuracy: 0.6576 - val_loss: 1.4849 - val_sparse_categorical_accuracy: 0.5096
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 1.2478 - sparse_categorical_accuracy: 0.5715
#             Model Name  Test Loss  Test Accuracy
# 0  Dense Model with BN   1.545087         0.4547
# 1    CNN Model with BN   1.247112         0.5719

# %%
# Теперь объединим оба DataFrame
results_df = pd.concat([results_df, r_df], ignore_index=True)

# Выводим финальный результат
print(results_df)
# Out:
#              Model Name  Test Loss  Test Accuracy Optimizer
# 0              MyModel1   1.489534         0.4685       NaN
# 1            CNN_Model1   1.218909         0.5696       NaN
# 2           Dense Model   1.492900         0.4700       NaN
# 3             CNN Model   1.228506         0.5598       NaN
# 4           Dense Model   1.477738         0.4761       SGD
# 5           Dense Model   1.512902         0.4616  Momentum
# 6           Dense Model   1.538135         0.4509      Adam
# 7             CNN Model   1.211614         0.5711       SGD
# 8             CNN Model   1.212484         0.5689  Momentum
# 9             CNN Model   1.154503         0.6054      Adam
# 10  Dense Model with BN   1.545087         0.4547       NaN
# 11    CNN Model with BN   1.247112         0.5719       NaN

# %% [markdown]
# Прокомментируйте полученные результаты.

# %% [markdown]
# Модели с нормализацией по батчу (Batch Normalization):
#    - Dense Model with BN: Потеряло 1.545087 и точность 0.4547. Здесь мы видим, что добавление нормализации по батчу не увеличило эффективность, а даже несколько ухудшило результаты по сравнению с базовойDense моделью.
#    - CNN Model with BN: Потеря 1.247112 и точность 0.5719, что демонстрирует небольшое улучшение по сравнению с другими CNN моделями. Нормализация по батчу, вероятно, помогла модели лучше адаптироваться к изменениям в данных.

# %% [markdown]
# **Задание 1.5 (опционально)** Посмотрите на batch_size (параметр model.fit) - при большем батче модель будет быстрее проходить эпохи, но с совсем огромным батчом вам потребуется больше эпох для сходимости (т.к. сеть делает меньше шагов за одну эпоху).
# Найдите такое значение, при котором модель быстрее достигает точности 55%. **Hint**: используйте early stopping callback.

# %%
import pandas as pd

# Создаем DataFrame для хранения результатов
re_df = pd.DataFrame(columns=['Batch Size', 'Model Name', 'Test Loss', 'Test Accuracy'])

# %%
batch_sizes = [16, 32, 64, 128]

# %%
# Словарь с моделями
models_dict = {
    "Dense Model": create_dense_model,
    "CNN Model": create_cnn_model
}

# Создаем список для хранения результатов вместо DataFrame напрямую
results = []

# Цикл по каждому размеру batch_size
for batch_size in batch_sizes:
    for model_name, model_creator in models_dict.items():
        # Создаем и обучаем модель
        model = model_creator()

        # Обучение модели
        early_stopping = EarlyStopping(monitor='val_sparse_categorical_accuracy', patience=5, restore_best_weights=True)
        history = model.fit(
            x_train, y_train,
            validation_data=(x_val, y_val),
            epochs=10,  # Настройка количества эпох
            batch_size=batch_size,
            callbacks=[early_stopping],
            verbose=1
        )

        # Оценка модели на тестовом наборе
        test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=0)

        # Добавляем результаты в список словарей
        results.append({
            'Batch Size': batch_size,
            'Model Name': model_name,
            'Test Loss': test_loss,
            'Test Accuracy': test_accuracy
        })

# Создаем DataFrame из списка результатов
re_df = pd.DataFrame(results)
# Out:
# Epoch 1/10
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - loss: 2.0186 - sparse_categorical_accuracy: 0.2702 - val_loss: 1.8068 - val_sparse_categorical_accuracy: 0.3417
# Epoch 2/10
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step - loss: 1.7490 - sparse_categorical_accuracy: 0.3760 - val_loss: 1.7001 - val_sparse_categorical_accuracy: 0.3894
# Epoch 3/10
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step - loss: 1.6440 - sparse_categorical_accuracy: 0.4144 - val_loss: 1.6662 - val_sparse_categorical_accuracy: 0.4013
# Epoch 4/10
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step - loss: 1.5908 - sparse_categorical_accuracy: 0.4343 - val_loss: 1.5696 - val_sparse_categorical_accuracy: 0.4353
# Epoch 5/10
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 20s 4ms/step - loss: 1.5347 - sparse_categorical_accuracy: 0.4534 - val_loss: 1.5774 - val_sparse_categorical_accuracy: 0.4397
# Epoch 6/10
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - loss: 1.5038 - sparse_categorical_accuracy: 0.4670 - val_loss: 1.5402 - val_sparse_categorical_accuracy: 0.4576
# Epoch 7/10
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 20s 5ms/step - loss: 1.4793 - sparse_categorical_accuracy: 0.4741 - val_loss: 1.5317 - val_sparse_categorical_accuracy: 0.4600
# Epoch 8/10
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 22s 5ms/step - loss: 1.4526 - sparse_categorical_accuracy: 0.4808 - val_loss: 1.5006 - val_sparse_categorical_accuracy: 0.4541
# Epoch 9/10
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 17s 3ms/step - loss: 1.4249 - sparse_categorical_accuracy: 0.4943 - val_loss: 1.4891 - val_sparse_categorical_accuracy: 0.4701
# Epoch 10/10
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 1.4078 - sparse_categorical_accuracy: 0.5001 - val_loss: 1.4749 - val_sparse_categorical_accuracy: 0.4735
# Epoch 1/10
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 32s 13ms/step - loss: 2.0042 - sparse_categorical_accuracy: 0.2736 - val_loss: 1.5308 - val_sparse_categorical_accuracy: 0.4505
# Epoch 2/10
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 42s 13ms/step - loss: 1.4783 - sparse_categorical_accuracy: 0.4710 - val_loss: 1.3544 - val_sparse_categorical_accuracy: 0.5237
# Epoch 3/10
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 29s 11ms/step - loss: 1.3153 - sparse_categorical_accuracy: 0.5362 - val_loss: 1.3022 - val_sparse_categorical_accuracy: 0.5339
# Epoch 4/10
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 28s 11ms/step - loss: 1.2237 - sparse_categorical_accuracy: 0.5645 - val_loss: 1.2513 - val_sparse_categorical_accuracy: 0.5602
# Epoch 5/10
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 29s 11ms/step - loss: 1.1511 - sparse_categorical_accuracy: 0.5945 - val_loss: 1.2040 - val_sparse_categorical_accuracy: 0.5716
# Epoch 6/10
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 41s 11ms/step - loss: 1.0944 - sparse_categorical_accuracy: 0.6176 - val_loss: 1.1641 - val_sparse_categorical_accuracy: 0.5920
# Epoch 7/10
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 48s 14ms/step - loss: 1.0440 - sparse_categorical_accuracy: 0.6324 - val_loss: 1.1728 - val_sparse_categorical_accuracy: 0.5955
# Epoch 8/10
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 34s 11ms/step - loss: 0.9901 - sparse_categorical_accuracy: 0.6506 - val_loss: 1.1613 - val_sparse_categorical_accuracy: 0.5926
# Epoch 9/10
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 28s 11ms/step - loss: 0.9415 - sparse_categorical_accuracy: 0.6675 - val_loss: 1.1397 - val_sparse_categorical_accuracy: 0.6058
# Epoch 10/10
# 2500/2500 ━━━━━━━━━━━━━━━━━━━━ 42s 12ms/step - loss: 0.8860 - sparse_categorical_accuracy: 0.6909 - val_loss: 1.1575 - val_sparse_categorical_accuracy: 0.6085
# Epoch 1/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 2.0425 - sparse_categorical_accuracy: 0.2579 - val_loss: 1.8115 - val_sparse_categorical_accuracy: 0.3441
# Epoch 2/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - loss: 1.7774 - sparse_categorical_accuracy: 0.3642 - val_loss: 1.7740 - val_sparse_categorical_accuracy: 0.3684
# Epoch 3/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 6ms/step - loss: 1.6934 - sparse_categorical_accuracy: 0.4009 - val_loss: 1.6745 - val_sparse_categorical_accuracy: 0.4023
# Epoch 4/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 1.6323 - sparse_categorical_accuracy: 0.4213 - val_loss: 1.6306 - val_sparse_categorical_accuracy: 0.4175
# Epoch 5/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 1.5919 - sparse_categorical_accuracy: 0.4366 - val_loss: 1.6683 - val_sparse_categorical_accuracy: 0.4068
# Epoch 6/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - loss: 1.5519 - sparse_categorical_accuracy: 0.4514 - val_loss: 1.5915 - val_sparse_categorical_accuracy: 0.4360
# Epoch 7/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 1.5240 - sparse_categorical_accuracy: 0.4573 - val_loss: 1.5478 - val_sparse_categorical_accuracy: 0.4515
# Epoch 8/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - loss: 1.4970 - sparse_categorical_accuracy: 0.4702 - val_loss: 1.5177 - val_sparse_categorical_accuracy: 0.4649
# Epoch 9/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - loss: 1.4709 - sparse_categorical_accuracy: 0.4805 - val_loss: 1.5209 - val_sparse_categorical_accuracy: 0.4636
# Epoch 10/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 1.4358 - sparse_categorical_accuracy: 0.4969 - val_loss: 1.4807 - val_sparse_categorical_accuracy: 0.4781
# Epoch 1/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 20ms/step - loss: 2.1010 - sparse_categorical_accuracy: 0.2284 - val_loss: 1.8006 - val_sparse_categorical_accuracy: 0.3631
# Epoch 2/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 41s 20ms/step - loss: 1.7172 - sparse_categorical_accuracy: 0.3925 - val_loss: 1.5616 - val_sparse_categorical_accuracy: 0.4498
# Epoch 3/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 41s 20ms/step - loss: 1.5382 - sparse_categorical_accuracy: 0.4600 - val_loss: 1.4693 - val_sparse_categorical_accuracy: 0.4762
# Epoch 4/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 40s 19ms/step - loss: 1.4334 - sparse_categorical_accuracy: 0.4944 - val_loss: 1.4502 - val_sparse_categorical_accuracy: 0.4962
# Epoch 5/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 41s 19ms/step - loss: 1.3558 - sparse_categorical_accuracy: 0.5237 - val_loss: 1.3301 - val_sparse_categorical_accuracy: 0.5330
# Epoch 6/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 26s 20ms/step - loss: 1.2842 - sparse_categorical_accuracy: 0.5487 - val_loss: 1.2989 - val_sparse_categorical_accuracy: 0.5384
# Epoch 7/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 40s 19ms/step - loss: 1.2364 - sparse_categorical_accuracy: 0.5629 - val_loss: 1.2895 - val_sparse_categorical_accuracy: 0.5452
# Epoch 8/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 40s 19ms/step - loss: 1.1952 - sparse_categorical_accuracy: 0.5792 - val_loss: 1.2819 - val_sparse_categorical_accuracy: 0.5540
# Epoch 9/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 22s 18ms/step - loss: 1.1502 - sparse_categorical_accuracy: 0.5999 - val_loss: 1.2277 - val_sparse_categorical_accuracy: 0.5716
# Epoch 10/10
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 42s 19ms/step - loss: 1.1241 - sparse_categorical_accuracy: 0.6066 - val_loss: 1.2238 - val_sparse_categorical_accuracy: 0.5753
# Epoch 1/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 2.0842 - sparse_categorical_accuracy: 0.2466 - val_loss: 1.8556 - val_sparse_categorical_accuracy: 0.3311
# Epoch 2/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - loss: 1.8290 - sparse_categorical_accuracy: 0.3543 - val_loss: 1.7597 - val_sparse_categorical_accuracy: 0.3717
# Epoch 3/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - loss: 1.7542 - sparse_categorical_accuracy: 0.3812 - val_loss: 1.7377 - val_sparse_categorical_accuracy: 0.3725
# Epoch 4/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - loss: 1.6988 - sparse_categorical_accuracy: 0.3999 - val_loss: 1.6892 - val_sparse_categorical_accuracy: 0.3922
# Epoch 5/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 1.6445 - sparse_categorical_accuracy: 0.4171 - val_loss: 1.6496 - val_sparse_categorical_accuracy: 0.4085
# Epoch 6/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 8s 11ms/step - loss: 1.6166 - sparse_categorical_accuracy: 0.4339 - val_loss: 1.6370 - val_sparse_categorical_accuracy: 0.4168
# Epoch 7/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 1.5892 - sparse_categorical_accuracy: 0.4409 - val_loss: 1.6199 - val_sparse_categorical_accuracy: 0.4185
# Epoch 8/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - loss: 1.5640 - sparse_categorical_accuracy: 0.4475 - val_loss: 1.6321 - val_sparse_categorical_accuracy: 0.4128
# Epoch 9/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - loss: 1.5471 - sparse_categorical_accuracy: 0.4548 - val_loss: 1.5537 - val_sparse_categorical_accuracy: 0.4448
# Epoch 10/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 9s 7ms/step - loss: 1.5224 - sparse_categorical_accuracy: 0.4648 - val_loss: 1.5502 - val_sparse_categorical_accuracy: 0.4464
# Epoch 1/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 21s 32ms/step - loss: 2.1579 - sparse_categorical_accuracy: 0.2098 - val_loss: 1.9132 - val_sparse_categorical_accuracy: 0.3314
# Epoch 2/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 32ms/step - loss: 1.8660 - sparse_categorical_accuracy: 0.3450 - val_loss: 1.8017 - val_sparse_categorical_accuracy: 0.3537
# Epoch 3/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 31ms/step - loss: 1.7448 - sparse_categorical_accuracy: 0.3872 - val_loss: 1.6707 - val_sparse_categorical_accuracy: 0.4085
# Epoch 4/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 19s 31ms/step - loss: 1.6472 - sparse_categorical_accuracy: 0.4218 - val_loss: 1.6830 - val_sparse_categorical_accuracy: 0.4027
# Epoch 5/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 21s 34ms/step - loss: 1.5732 - sparse_categorical_accuracy: 0.4437 - val_loss: 1.5178 - val_sparse_categorical_accuracy: 0.4621
# Epoch 6/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 41s 33ms/step - loss: 1.4933 - sparse_categorical_accuracy: 0.4756 - val_loss: 1.4748 - val_sparse_categorical_accuracy: 0.4831
# Epoch 7/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 40s 32ms/step - loss: 1.4337 - sparse_categorical_accuracy: 0.4947 - val_loss: 1.4120 - val_sparse_categorical_accuracy: 0.5078
# Epoch 8/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 21s 32ms/step - loss: 1.3918 - sparse_categorical_accuracy: 0.5107 - val_loss: 1.4272 - val_sparse_categorical_accuracy: 0.4968
# Epoch 9/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 32ms/step - loss: 1.3610 - sparse_categorical_accuracy: 0.5198 - val_loss: 1.3677 - val_sparse_categorical_accuracy: 0.5160
# Epoch 10/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 31ms/step - loss: 1.3155 - sparse_categorical_accuracy: 0.5388 - val_loss: 1.3418 - val_sparse_categorical_accuracy: 0.5250
# Epoch 1/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - loss: 2.1329 - sparse_categorical_accuracy: 0.2183 - val_loss: 1.9187 - val_sparse_categorical_accuracy: 0.3164
# Epoch 2/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 1.8965 - sparse_categorical_accuracy: 0.3273 - val_loss: 1.8748 - val_sparse_categorical_accuracy: 0.3238
# Epoch 3/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 1.8220 - sparse_categorical_accuracy: 0.3582 - val_loss: 1.7796 - val_sparse_categorical_accuracy: 0.3695
# Epoch 4/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 1.7795 - sparse_categorical_accuracy: 0.3715 - val_loss: 1.7564 - val_sparse_categorical_accuracy: 0.3703
# Epoch 5/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 1.7290 - sparse_categorical_accuracy: 0.3955 - val_loss: 1.7383 - val_sparse_categorical_accuracy: 0.3834
# Epoch 6/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 1.7001 - sparse_categorical_accuracy: 0.4051 - val_loss: 1.7279 - val_sparse_categorical_accuracy: 0.3872
# Epoch 7/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - loss: 1.6662 - sparse_categorical_accuracy: 0.4140 - val_loss: 1.6876 - val_sparse_categorical_accuracy: 0.4046
# Epoch 8/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 1.6568 - sparse_categorical_accuracy: 0.4221 - val_loss: 1.6690 - val_sparse_categorical_accuracy: 0.4088
# Epoch 9/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 1.6310 - sparse_categorical_accuracy: 0.4284 - val_loss: 1.7095 - val_sparse_categorical_accuracy: 0.3852
# Epoch 10/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step - loss: 1.6039 - sparse_categorical_accuracy: 0.4382 - val_loss: 1.6469 - val_sparse_categorical_accuracy: 0.4098
# Epoch 1/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 22s 68ms/step - loss: 2.2450 - sparse_categorical_accuracy: 0.1671 - val_loss: 2.0321 - val_sparse_categorical_accuracy: 0.2735
# Epoch 2/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 18s 59ms/step - loss: 1.9789 - sparse_categorical_accuracy: 0.3042 - val_loss: 1.9554 - val_sparse_categorical_accuracy: 0.2808
# Epoch 3/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - loss: 1.8635 - sparse_categorical_accuracy: 0.3419 - val_loss: 1.8273 - val_sparse_categorical_accuracy: 0.3507
# Epoch 4/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 21s 60ms/step - loss: 1.7876 - sparse_categorical_accuracy: 0.3717 - val_loss: 1.8018 - val_sparse_categorical_accuracy: 0.3542
# Epoch 5/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 20s 58ms/step - loss: 1.7297 - sparse_categorical_accuracy: 0.3918 - val_loss: 1.7074 - val_sparse_categorical_accuracy: 0.3899
# Epoch 6/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 23s 67ms/step - loss: 1.6731 - sparse_categorical_accuracy: 0.4092 - val_loss: 1.6463 - val_sparse_categorical_accuracy: 0.4154
# Epoch 7/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 18s 57ms/step - loss: 1.6084 - sparse_categorical_accuracy: 0.4361 - val_loss: 1.5989 - val_sparse_categorical_accuracy: 0.4280
# Epoch 8/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 22s 62ms/step - loss: 1.5674 - sparse_categorical_accuracy: 0.4472 - val_loss: 1.5449 - val_sparse_categorical_accuracy: 0.4468
# Epoch 9/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 18s 57ms/step - loss: 1.5276 - sparse_categorical_accuracy: 0.4628 - val_loss: 1.5172 - val_sparse_categorical_accuracy: 0.4560
# Epoch 10/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 21s 58ms/step - loss: 1.4929 - sparse_categorical_accuracy: 0.4714 - val_loss: 1.4820 - val_sparse_categorical_accuracy: 0.4748

# %%
# Вывод результатов
print(re_df)
# Out:
#    Batch Size   Model Name  Test Loss  Test Accuracy
# 0          16  Dense Model   1.459000         0.4827
# 1          16    CNN Model   1.156128         0.6051
# 2          32  Dense Model   1.468929         0.4770
# 3          32    CNN Model   1.226206         0.5696
# 4          64  Dense Model   1.541699         0.4528
# 5          64    CNN Model   1.338782         0.5186
# 6         128  Dense Model   1.634956         0.4143
# 7         128    CNN Model   1.484150         0.4641

# %% [markdown]
# Видно, что для Dense моделей точность снизилась с увеличением размера батча. Это может быть связано с тем, что большие батчи мешают модели лучше обобщаться, так как они шажками меньше адаптируются к данным, и, соответственно, могут не максимизировать свою производительность. В частности, на больших батчах, модель получает меньше шагов обновления параметров за эпоху, что может привести к меньшему количеству локальных минимумов, а значит, более низким окончательным результатам.
#
#
# Для CNN модели, общее направление также показывает снижение точности с увеличением размера батча, но начальная точность для батча 16 достаточно высока и даже превышает 55%. Возможно, на этом размерности обучалка сохранила общий эффект градиентного спуска, что привело к более высокой производительности. Однако при увеличении размера батча модель демонстрирует свои недостатки.

# %% [markdown]
# **Задание 1.6 (опционально)** Попробуйте найти такую комбинацию метода обучения и нормализации, при которой сеть имеет наилучшую кривую обучения. Поясните, что вы понимаете под "наилучшей" кривой обучения.

# %%
def plot_learning_curves(history, model_description):
    plt.figure(figsize=(12, 4))

    # Accuracy
    plt.subplot(1, 2, 1)
    plt.plot(history.history['sparse_categorical_accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_sparse_categorical_accuracy'], label='Validation Accuracy')
    plt.title(f'{model_description} Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    # Loss
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title(f'{model_description} Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.show()

# %%
from tensorflow.keras import layers, models

def create_model(optimizer='adam', normalization='batch'):
    model = models.Sequential()

    # Используем InputLayer для определения формы входных данных
    model.add(layers.Input(shape=(32, 32, 3)))  # размер изображений

    model.add(layers.Conv2D(32, (3, 3), activation='relu'))
    if normalization == 'batch':
        model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((2, 2)))

    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    if normalization == 'batch':
        model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((2, 2)))

    model.add(layers.Flatten())
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dense(10, activation='softmax'))

    model.compile(optimizer=optimizer,
                  loss='sparse_categorical_crossentropy',
                  metrics=['sparse_categorical_accuracy'])

    return model

# %%
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.callbacks import EarlyStopping

# Параметры для обучения
batch_size = 64
epochs = 10

# Функция для обучения модели
def train_model(optimizer, normalization):
    model = create_model(optimizer=optimizer, normalization=normalization)

    # Установка обратного вызова для ранней остановки
    early_stopping = EarlyStopping(monitor='val_loss', patience=3)

    history = model.fit(x_train, y_train,
                        batch_size=batch_size,
                        epochs=epochs,
                        validation_split=0.2,
                        callbacks=[early_stopping],
                        verbose=0)  # Меньше вывода во время обучения

    return history

# Пример обучения с Adam и Batch Normalization
history = train_model(optimizer='adam', normalization='batch')

# %%
plot_learning_curves(history, "Adam + Batch Normalization")

# Обучение и построение графиков для других комбинаций
history_sgd_bn = train_model(optimizer='sgd', normalization='batch')
plot_learning_curves(history_sgd_bn, "SGD + Batch Normalization")

history_adam_ln = train_model(optimizer='adam', normalization='layer')
plot_learning_curves(history_adam_ln, "Adam + Layer Normalization")

history_sgd_gn = train_model(optimizer='sgd', normalization='group')
plot_learning_curves(history_sgd_gn, "SGD + Group Normalization")

# %% [markdown]
# Пример обучения с "SGD + Group Normalization" демонстриет стремление к максимальной обучающей и валидационной точности.

# %% [markdown]
# Ключевые характеристики "наилучшей" кривой обучения:
#
# 1. Сходимость к высокой точности: Наилучшие кривые обучения демонстрируют стремление к максимальной обучающей и валидационной точности. Идеально, если обе кривые указывают на то, что модель хорошо воспроизводит данные, достигая высокого уровня точности на валидационном наборе.
#
# 2. Минимизация потерь: Наилучшие кривые обучения показывают стремление к снижению значений потери (loss) на тренировочном и валидационном уровнях. Потеря должна снижаться по мере увеличения числа эпох, что указывает на то, что модель обучается и улучшает свои параметры.
#
# 3. Отсутствие переобучения: Наилучшие кривые должны отображать равномерное снижение потерь для обучающего и валидационного наборов, без значительных расхождений. Переобучение проявляется в том, что обучающая точность продолжает расти, тогда как валидационная точность начинает падать или становится фиксированной. Наилучшие кривые не должны демонстрировать резкие различия между потерь/точностью на training и validation.
#
# 4. Стабильность и плавность: Идеальная кривая должна быть плавной и без резких колебаний, что указывает на устойчивое общее поведение модели. Небольшие колебания могут встречаться, особенно в ранних эпохах, но они не должны быть слишком сильными.
#
# 5. Достижение плато: Кривые обучения должны показывать достижение плато — состояние, когда дальнейшее обучение не приводит к значительным улучшениям. Это может указывать на то, что модель достигла своей предельной производительности.
#
# 6. Влияние нормализации и оптимизации: Разные методики нормализации и оптимизации могут оказывать выраженное влияние на кривые обучения. Например, использование Batch Normalization может ускорить сходимость и улучшить общую производительность модели.

# %% [markdown]
# ## Свёрточная нейросеть здорового человека
#
# **Задание 1.7 (обязательно попытаться)** Наигравшись выше, обучим большую свёрточную сеть, которая даст на тестовой выборке __accuracy больше 80%__. В этом задании вам потребуется провести эксперименты, сравнив их между собой в конце. Возможно, может быть несколько проще, если писать выводы во время или сразу после каждого эксперимента, после чего сделать общие выводы.
#
# Рекомендуем начать с лучшей модели предыдущего задания и постепенно её улучшать. Вы можете использовать всё, что угодно: любые активации, сколь угодно большие свёрточные слои и глубокие сети. Единственное ограничение: __нельзя использовать предобученные сети и дополнительные данные__.
#
# ### Полезные советы
# * Для начала, неплохо бы научить что-нибудь побольше, чем 10 фильтров 3x3.
# * __Главное правило: одно изменение на эксперимент__. Если у вас есть 2 идеи по улучшению сети, сначала попробуйте их независимо. Может оказаться, что одно из них дало __+10%__ точности а другое __-7%__. А вы так и будете думать, что сделали 2 полезных изменения которые в сумме дают __+3%__. Если какая-то идея не работает — даже если она вам нравится - опишите ее и выкидывайте из дальнейших экспериментов.
# * __Be careful or you will dropout__. Дропаут (`L.Dropout`) может позволить вам обучить в несколько раз бОльшую сеть без переобучения, выжав несколько процентов качества. Это круто, но не стоит сразу ставить dropout 50%. Во-первых, слишком сильный дропаут только ухудшит сеть (underfitting). Во-вторых, даже если дропаут улучшает качество, он замедляет обучение. Рекомендуем начинать с небольшого дропаута, быстро провести основные эксперименты, а потом жахнуть в 2 раза больше нейронов и дропаута ~~на ночь~~.
# * __Аугментация данных__. Если котика слегка повернуть и подрезать (простите), он всё равно останется котиком. А в керасе есть [удобный класс](https://keras.io/preprocessing/image/), который поставит подрезание котиков на поток. Ещё можно сделать этот трюк в тесте: вертим картинку 10 раз, предсказываем вероятности и усредняем. Только один совет: прежде, чем учить, посмотрите глазами на аугментированные картинки. Если вы сами не можете их различить, то и сеть не сможет.
# * __Don't just stack more layers__. Есть более эффективные способы организовать слои, чем простой Sequential. Вот пара идей: [Inception family](https://hacktilldawn.com/2016/09/25/inception-modules-explained-and-implemented/), [ResNet family](https://towardsdatascience.com/an-overview-of-resnet-and-its-variants-5281e2f56035?gi=9018057983ca), [Densely-connected convolutions](https://arxiv.org/abs/1608.06993). Только не копируйте архитектуру подчистую — вам скорее всего хватит меньшего размера.
# * __Долго != плохо__. Более глубокие архитектуры обычно требуют бОльше эпох до сходимости. Это значит, что в первые несколько эпох они могут быть хуже менее глубоких аналогов. Дайте им время, запаситесь чаем и обмажьтесь batch-norm-ом.

# %% [markdown]
# Создание базовой свёрточной модели:

# %%
from tensorflow.keras import layers, models

def create_base_cnn_model():
    model = models.Sequential()
    model.add(layers.Input(shape=(32, 32, 3)))

    # Свёрточные слои
    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((2, 2)))

    model.add(layers.Conv2D(128, (3, 3), activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((2, 2)))

    model.add(layers.Conv2D(256, (3, 3), activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((2, 2)))

    model.add(layers.Flatten())

    # Полносвязные слои
    model.add(layers.Dense(512, activation='relu'))
    model.add(layers.Dropout(0.5))  # Dropout для предотвращения переобучения
    model.add(layers.Dense(10, activation='softmax'))

    # Компиляция модели
    model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['sparse_categorical_accuracy'])

    return model

# %% [markdown]
# Обучение и оценка модели

# %%
model = create_base_cnn_model()
early_stopping = EarlyStopping(monitor='val_sparse_categorical_accuracy', patience=5, restore_best_weights=True)

history = model.fit(x_train, y_train,
                    validation_data=(x_val, y_val),
                    epochs=50,
                    batch_size=64,
                    callbacks=[early_stopping],
                    verbose=1)

test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f"Test Loss: {test_loss}, Test Accuracy: {test_accuracy}")
# Out:
# Epoch 1/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 223s 352ms/step - loss: 1.8663 - sparse_categorical_accuracy: 0.3861 - val_loss: 1.3809 - val_sparse_categorical_accuracy: 0.4988
# Epoch 2/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 261s 351ms/step - loss: 1.1677 - sparse_categorical_accuracy: 0.5903 - val_loss: 1.0137 - val_sparse_categorical_accuracy: 0.6455
# Epoch 3/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 261s 350ms/step - loss: 0.9437 - sparse_categorical_accuracy: 0.6702 - val_loss: 1.2792 - val_sparse_categorical_accuracy: 0.5821
# Epoch 4/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 262s 350ms/step - loss: 0.7955 - sparse_categorical_accuracy: 0.7246 - val_loss: 0.9748 - val_sparse_categorical_accuracy: 0.6720
# Epoch 5/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 261s 348ms/step - loss: 0.6905 - sparse_categorical_accuracy: 0.7588 - val_loss: 0.8291 - val_sparse_categorical_accuracy: 0.7226
# Epoch 6/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 216s 346ms/step - loss: 0.6002 - sparse_categorical_accuracy: 0.7918 - val_loss: 0.9435 - val_sparse_categorical_accuracy: 0.6898
# Epoch 7/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 260s 343ms/step - loss: 0.5026 - sparse_categorical_accuracy: 0.8228 - val_loss: 1.1453 - val_sparse_categorical_accuracy: 0.6826
# Epoch 8/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 266s 349ms/step - loss: 0.4445 - sparse_categorical_accuracy: 0.8460 - val_loss: 0.8629 - val_sparse_categorical_accuracy: 0.7390
# Epoch 9/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 265s 355ms/step - loss: 0.3793 - sparse_categorical_accuracy: 0.8686 - val_loss: 1.0102 - val_sparse_categorical_accuracy: 0.7036
# Epoch 10/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 258s 349ms/step - loss: 0.3278 - sparse_categorical_accuracy: 0.8850 - val_loss: 1.1109 - val_sparse_categorical_accuracy: 0.7100
# Epoch 11/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 221s 353ms/step - loss: 0.2877 - sparse_categorical_accuracy: 0.8979 - val_loss: 0.9210 - val_sparse_categorical_accuracy: 0.7574
# Epoch 12/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 218s 349ms/step - loss: 0.2401 - sparse_categorical_accuracy: 0.9176 - val_loss: 1.5742 - val_sparse_categorical_accuracy: 0.6600
# Epoch 13/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 264s 352ms/step - loss: 0.2435 - sparse_categorical_accuracy: 0.9148 - val_loss: 1.1172 - val_sparse_categorical_accuracy: 0.7305
# Epoch 14/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 220s 353ms/step - loss: 0.2019 - sparse_categorical_accuracy: 0.9291 - val_loss: 1.3310 - val_sparse_categorical_accuracy: 0.7088
# Epoch 15/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 217s 348ms/step - loss: 0.1888 - sparse_categorical_accuracy: 0.9355 - val_loss: 1.2374 - val_sparse_categorical_accuracy: 0.7363
# Epoch 16/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 267s 356ms/step - loss: 0.1734 - sparse_categorical_accuracy: 0.9404 - val_loss: 1.1275 - val_sparse_categorical_accuracy: 0.7492
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 13s 42ms/step - loss: 0.9134 - sparse_categorical_accuracy: 0.7597
# Test Loss: 0.9330969452857971, Test Accuracy: 0.7555999755859375

# %% [markdown]
# Момент истины: проверьте, какого качества достигла ваша сеть.

# %%
print(f"Test Loss: {test_loss}, Test Accuracy: {test_accuracy}")
# Out:
# Test Loss: 0.9330969452857971, Test Accuracy: 0.7555999755859375

# %% [markdown]
# А теперь, опишите свои <s>ощущения</s> результаты от проведенных экспериментов.

# %% [markdown]
# Проведённый эксперимент с базовой свёрточной нейросетью привел к следующему результату:
# - Потеря на тестовой выборке (Test Loss): 0.933
# - Точность на тестовой выборке (Test Accuracy): 75.6%
#
# Это значение ниже целевого порога в 80%. Несмотря на наличие нескольких свёрточных слоев, применения нормализации (BatchNormalization) и дропаута, модель не смогла достичь требуемой точности.
