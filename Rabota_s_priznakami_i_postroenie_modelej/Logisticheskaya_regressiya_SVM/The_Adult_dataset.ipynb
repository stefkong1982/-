# %% [markdown]
# ### **Непрерывные атрибуты:**

# %% [markdown]
# 1. **age** - Возраст. Этот атрибут представляет собой числовое значение, обозначающее возраст индивида. Возраст является важным демографическим показателем и может играть роль в анализе данных, а также в прогнозировании поведения и принятии решений.
#
# Знание возраста человека может помочь в определении его физических и психологических характеристик, а также в оценке его потребностей, уровня активности и социальной адаптации. Возраст также может влиять на финансовое положение, культурные предпочтения, жизненный опыт и другие аспекты жизни индивида.
#
# Анализ возраста может помочь в проведении целевых кампаний, создании персонализированных продуктов и услуг, определении тенденций и прогнозировании изменений в обществе. Определение возраста и его учет при анализе данных является важным инструментом для понимания поведения и потребностей различных групп людей, что может быть полезно для различных сфер деятельности, включая маркетинг, медицину, образование, социологию и другие области.
#
# 2. **fnlwgt** - final weight. В случае базы данных adult, параметр fnlwgt представляет собой оценку веса каждой записи в выборке с учетом общей популяции. В данном случае, fnlwgt может быть использован как признак при обучении модели машинного обучения, но прежде чем это сделать, стоит провести анализ влияния данного признака на предсказываемую переменную (class: >50K, <=50K).
#
# Перед использованием fnlwgt в модели, следует провести исследование на корреляцию данного признака с целевой переменной, а также на его важность для модели. Также можно провести анализ влияния fnlwgt на точность и стабильность модели, чтобы оценить, действительно ли этот признак значим для прогнозирования целевой переменной.
#
# Если после анализа будет обнаружено, что fnlwgt не оказывает значительного влияния на целевую переменную или усложняет обучение модели, то можно принять решение исключить его из анализа. Если же fnlwgt демонстрирует важное влияние на прогнозирование, то его можно использовать в качестве признака в модели.
#
# Поэтому, перед использованием fnlwgt как признака для обучения модели, рекомендуется провести дополнительный анализ его влияния на данные и модель, чтобы принять обоснованное решение по его использованию.
#
# 3. **capital-gain** - Прирост капитала. В данном атрибуте указывается сумма капитала, которая была получена индивидом в результате продажи ценных бумаг, недвижимости или других активов, превышающая исходную стоимость приобретения этих активов. Capital gain является одним из показателей доходности инвестиций и может отражать финансовый успех индивида.
#
# Капитал-выигрыш может возникать при продаже активов по более высокой цене, чем они были приобретены, и отражает прирост капитала индивида в результате успешных инвестиций или торговли. Этот параметр может использоваться для оценки финансовой состоятельности, инвестиционной активности и финансового управления индивида.
#
# Анализ capital-gain может помочь в понимании доходности инвестиций и выявлении индивидов, которые успешно управляют своими активами. Этот атрибут также может быть полезен для выявления финансовых тенденций, оценки финансового риска и прогнозирования финансовых результатов. Важно учитывать, что capital-gain играет важную роль в финансовом планировании и управлении личными финансами.
#
# 4. **capital-loss** - Потери капитала. Этот атрибут указывает сумму капитала, которую индивид потерял при продаже ценных бумаг, недвижимости или других активов, и которая превышает первоначальную стоимость приобретения этих активов. Capital loss является важным финансовым показателем, который отражает убыточные сделки или инвестиции.
#
# Потери капитала могут возникать, когда активы продаются по более низкой цене, чем цена их приобретения, и в результате индивид теряет часть инвестированных средств. Учет потерь капитала важен для оценки финансового риска, эффективности инвестиций и общего финансового благополучия.
#
# Анализ capital-loss может помочь в понимании убыточных операций и источников финансовых потерь у индивида. Он может быть использован для оценки финансового здоровья, управления рисками и принятии финансовых решений. Учет как прироста, так и потерь капитала позволяет получить полное представление об индивидуальных финансовых активах и результате финансовых операций. Важно учитывать capital-loss как важный показатель при финансовом анализе и планировании.
#
# 5. **hours-per-week** - Часы работы в неделю. Этот атрибут представляет собой числовое значение, указывающее на количество часов, которые индивид проводит на работе в неделю. Количество часов работы в неделю является важным фактором при определении статуса занятости, заработной платы, рабочего времени и профессиональных обязанностей.
#
# Часы работы в неделю могут варьироваться в зависимости от типа работы, обязанностей, профессии, организации и личных предпочтений индивида. Анализ этого атрибута позволяет понять уровень занятости, объем работы, рабочие условия и профессиональные привычки индивида.
#
# Знание количества часов работы в неделю может помочь в оценке уровня дохода, баланса между работой и личной жизнью, профессиональных возможностей и общего благосостояния. Этот параметр также может быть использован для определения рабочих норм, оценки трудовой активности и анализа трудовой продуктивности. Наличие информации о часах работы в неделю позволяет более детально изучать трудовые характеристики индивида и проводить анализ данных о занятости.

# %% [markdown]
# ### **Категориальные атрибуты:**

# %% [markdown]
# 6. **workclass** - Класс работы. В данном атрибуте указывается тип работы или сфера занятости индивида и может принимать различные значения, отражающие его профессиональный статус и сферу деятельности. Некоторые из возможных значений включают:
#
# - Private: Частный сектор
# - Self-emp-not-inc: Самозанятый (без учета инкорпорации)
# - Self-emp-inc: Самозанятый (с учетом инкорпорации)
# - Federal-gov: Федеральное правительство
# - Local-gov: Местное правительство
# - State-gov: Штатовское правительство
# - Without-pay: Без оплаты
# - Never-worked: Никогда не работал
#
# Этот атрибут предоставляет информацию о типе занятости или организации, где работает человек, что может быть важным фактором при анализе данных о доходах, статусе занятости и социоэкономическом положении. Знание класса работы позволяет более точно оценить профессиональные характеристики и возможности индивида, а также выявить различия в доходах и условиях труда в зависимости от типа занятости. Каждое значение этого атрибута представляет определенный класс работы, который может быть использован для анализа данных и принятия соответствующих решений.
#
# 7. **education** - Образование. В данном атрибуте указывается уровень образования, достигнутый индивидом, что является важным фактором при анализе данных, оценке работоспособности и определении потенциальных возможностей на рынке труда. Варианты значений могут включать, но не ограничиваться:
#
# - Bachelors: Бакалавр
# - Some-college: Некоторое колледжевское образование
# - 11th: 11-й класс
# - HS-grad: Среднее образование
# - Prof-school: Профессиональная школа (например, медицинский колледж)
# - Assoc-acdm: Диплом ассоциированного академического образования
# - Assoc-voc: Диплом ассоциированного профессионального образования
# - 9th: 9-й класс
# - 7th-8th: 7-8 классы
# - 12th: 12-й класс
# - Masters: Магистр
# - 1st-4th: 1-4 классы
# - 10th: 10-й класс
# - Doctorate: Докторская степень
# - 5th-6th: 5-6 классы
# - Preschool: Дошкольное образование
#
# Этот атрибут позволяет оценить уровень образования индивида, что может влиять на его шансы на рынке труда, возможности карьерного роста, доход и общественный статус. Знание образовательного уровня может также помочь в прогнозировании социальной мобильности и предсказании потенциальных успехов или трудностей в профессиональной деятельности. Каждое значение этого атрибута отражает определенный уровень образования, который может быть использован для проведения анализа данных и выявления тенденций в сфере образования и трудоустройства.
#
# 8. **education-num** - Число образования. В данном атрибуте указан числовой код, соответствующий уровню образования индивида. Этот атрибут представляет собой числовое представление уровня образования, указанного в атрибуте education. Например, бакалавриат может быть обозначен числом 13, а среднее образование - числом 9.
#
# Числовое представление уровня образования помогает в стандартизации данных и упрощает их анализ. Использование числовых значений позволяет проводить математические операции и сравнивать уровни образования напрямую. Этот атрибут предоставляет более абстрактное и обобщенное представление об образовании индивида, что может быть полезным для статистического анализа, машинного обучения и других техник обработки данных.
#
# Важно отметить, что значения education-num соответствуют значениям образования в атрибуте education, и эти числа представляют различные уровни образования, от начального образования до докторской степени. Использование числового представления уровня образования может облегчить работу с данными и сделать их более удобными для анализа и интерпретации.
#
# 9. **marital-status** - Семейное положение. В этом атрибуте представлено семейное положение человека и может принимать значения:
#
# - Married-civ-spouse: Замужем/женат (гражданский брак)
# - Divorced: Разведен(а)
# - Never-married: Никогда не был(а) женат/замужем
# - Separated: Разведен(а) (живет отдельно от партнера)
# - Widowed: Овдовевший(ая)
# - Married-spouse-absent: В браке, супруг(-а) отсутствует
# - Married-AF-spouse: В браке с военнослужащим (-ой) ВВС
#
# Этот атрибут позволяет оценить семейное положение индивида, что может быть важным фактором при проведении анализа в базе данных и оценке дохода или других характеристик. Каждое из указанных значений представляет определенное семейное положение, которое может быть учтено при анализе данных или принятии решений.
#
#
# 10. **occupation** - Занятость. В этом атрибуте представлена профессиональная деятельность человека и может принимать различные значения в зависимости от рода занятия. Варианты значений включают, но не ограничиваются:
#
# - Tech-support: Техническая поддержка
# - Craft-repair: Ремесло, ремонт
# - Other-service: Другие услуги
# - Sales: Продажи
# - Exec-managerial: Исполнительский, управленческий
# - Prof-specialty: Профессиональная специальность
# - Handlers-cleaners: Работники, чистильщики
# - Machine-op-inspct: Оператор машины, инспектор
# - Adm-clerical: Административный, клерикальный
# - Farming-fishing: Сельское хозяйство, рыболовство
# - Transport-moving: Транспорт, перемещение
# - Priv-house-serv: Частный домашний персонал
# - Protective-serv: Охранная служба
# - Armed-Forces: Вооруженные силы
#
# Этот атрибут предоставляет информацию о виде профессиональной деятельности индивида, что может быть полезно при анализе данных о доходах, образовании и других характеристиках. Занятость может сказать о статусе работы и уровне заработной платы, а также о социальном статусе и образовании человека. Каждое значение этого атрибута представляет конкретную профессиональную область деятельности, которая также может быть важным фактором при оценке данных и проведении анализа.
#
# 11. **relationship** - Отношения. В этом атрибуте представлено тип отношений с другими людьми у индивида и может принимать различные значения, отражающие степень близости и связи с другими людьми. Некоторые из возможных значений включают:
#
# - Wife: Жена
# - Own-child: Собственный ребенок
# - Husband: Муж
# - Not-in-family: Не в семье
# - Other-relative: Другие родственники
# - Unmarried: Не женат/не замужем
#
# Этот атрибут позволяет оценить тип отношений, которые человек имеет с другими лицами, и определить его положение в семье или общественных связях. Знание о типе отношений может быть важным фактором при анализе данных, так как это может влиять на некоторые аспекты жизни и принимаемые решения. Каждое значение этого атрибута представляет определенный тип отношений, который может быть учтен при анализе и интерпретации данных.
#
# 12. **race** - Раса. В этом атрибуте представлено принадлежность к определенной расовой группе, что может быть важным фактором при анализе данных и оценке социокультурных характеристик человека. Варианты значений могут включать:
#
# - White: Белая раса
# - Asian-Pac-Islander: Азиатско-тихоокеанская раса
# - Amer-Indian-Eskimo: Американо-индейско-эскимосская раса
# - Other: Другие расы
# - Black: Афроамериканская раса
#
# Этот атрибут предоставляет информацию о расовой принадлежности индивида, что может оказать влияние на его социальное статус, культурные особенности, уровень образования и другие аспекты жизни. Понимание расовой и этнической принадлежности человека может помочь в проведении анализа данных, оценке степени разнообразия или неравенства в обществе, а также при принятии решений в сфере социального и социокультурного развития. Каждое значение этого атрибута представляет конкретную расовую группу, которая может быть учтена при анализе социологических данных.
#
# 13. **gender** - Пол. В данном атрибуте указывается пол индивида и может принимать два значения:
#
# - Male: Мужской
# - Female: Женский
#
# Этот атрибут предоставляет информацию о биологическом поле человека, что является важным аспектом при анализе данных, принятии решений и проведении социологических исследований. Знание пола индивида может быть полезным для понимания различий в образовании, доходах, рабочих местах, социокультурных практиках и других аспектах жизни. Пол также может играть роль в определении социальных ролей и стереотипов, которые могут влиять на возможности и перспективы человека в обществе.
#
# Каждое значение этого атрибута представляет бинарное разделение по половому признаку, которое может быть учтено при анализе данных, гендерном исследовании или при проведении социальных анализов и исследований для более глубокого понимания общественных процессов и явлений.
#
# 14. **native-country** - Родная страна. В данном атрибуте указывается страна, в которой родился индивид или страна, с которой связаны его корни и культурные особенности. Значения данного атрибута могут включать, но не ограничиваться:
#
# - United-States: Соединенные Штаты Америки
# - Cambodia: Камбоджа
# - England: Англия
# - Germany: Германия
# - Canada: Канада
# - Outlying-US(Guam-USVI-etc): Внешние территории США
# - India: Индия
# - Japan: Япония
# - Greece: Греция
# - South: Южная Корея
# - China: Китай
# - Cuba: Куба
# - Iran: Иран
# - Jamaica: Ямайка
#
# Этот атрибут предоставляет информацию о культурном и этническом происхождении индивида, а также о его месте рождения или стране, с которой у него связаны корни. Знание родной страны человека может помочь в проведении анализа данных, выявлении разнообразия культур и понимании многообразия, которое присутствует среди населения. Учет родной страны также может быть важным при оценке образования, статуса деловых партнеров, миграционных потоков и других аспектов социокультурного развития. Каждое значение этого атрибута представляет конкретную страну, что может быть полезным для проведения анализа и интерпретации данных.
#
# 15. **class** - Уровень дохода. (в нашем случее `income`)В базе данных "The Adult dataset" атрибут "class" представляет собой целевую переменную, которую модель машинного обучения пытается предсказать или классифицировать. В данной базе данных "class" указывает на то, превысит ли доход лицо уровень $50,000 в год ( ">50K" ) или нет ( "<=50K" ). Этот атрибут является ключевым для задачи бинарной классификации для предсказания дохода индивидов на основе других признаков, содержащихся в наборе данных.
#
# Анализ и понимание атрибута "class" в базе данных "The Adult dataset" позволяют построить модель машинного обучения, которая способна предсказывать, превысит ли доход индивида уровень $50,000 в год. Для решения этой задачи классификации могут использоваться различные алгоритмы, такие как логистическая регрессия, деревья решений, случайные леса, метод ближайших соседей и другие.
#
# Исследование атрибута "class" в базе данных "The Adult dataset" позволяет определить цель и задачу анализа данных, а также выбрать подходящий метод машинного обучения для построения прогностических моделей и определения факторов, которые влияют на доход индивидов. Данное понимание также помогает в оценке качества модели и ее способности корректно классифицировать доход на основе имеющихся данных.
