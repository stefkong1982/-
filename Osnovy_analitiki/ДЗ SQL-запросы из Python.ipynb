# %% [markdown]
# Домашнее задание «Откуда берутся данные»

# %%
# !python -m pip install --upgrade 'sqlalchemy<2.0’
# Out:
# /bin/bash: -c: line 0: unexpected EOF while looking for matching `''
# /bin/bash: -c: line 1: syntax error: unexpected end of file

# %%
import pandas as pd

# %%
df_country = pd.read_sql(
"""
select
  *
from
  country;
""",
"postgresql://netology:NetoSQL2019@84.201.153.170:19001/world-db"
)

# %%
df_country.head()
# Out:
#   code                  name      continent                     region  \
# 0  AFG           Afghanistan           Asia  Southern and Central Asia
# 1  NLD           Netherlands         Europe             Western Europe
# 2  ANT  Netherlands Antilles  North America                  Caribbean
# 3  ALB               Albania         Europe            Southern Europe
# 4  DZA               Algeria         Africa            Northern Africa
#
#    surface_area  indep_year  population  life_expectancy       gnp   gnp_old  \
# 0      652090.0      1919.0    22720000             45.9    5976.0       NaN
# 1       41526.0      1581.0    15864000             78.3  371362.0  360478.0
# 2         800.0         NaN      217000             74.7    1941.0       NaN
# 3       28748.0      1912.0     3401200             71.6    3205.0    2500.0
# 4     2381740.0      1962.0    31471000             69.7   49982.0   46966.0
#
#               local_name                               government_form  \
# 0  Afganistan/Afqanestan                               Islamic Emirate
# 1              Nederland                       Constitutional Monarchy
# 2   Nederlandse Antillen  Nonmetropolitan Territory of The Netherlands
# 3              Shqipëria                                      Republic
# 4     Al-Jazair/Algérie                                      Republic
#
#           head_of_state  capital code2
# 0         Mohammad Omar      1.0    AF
# 1               Beatrix      5.0    NL
# 2               Beatrix     33.0    AN
# 3        Rexhep Mejdani     34.0    AL
# 4  Abdelaziz Bouteflika     35.0    DZ

# %%
df_country.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239 entries, 0 to 238
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   code             239 non-null    object
#  1   name             239 non-null    object
#  2   continent        239 non-null    object
#  3   region           239 non-null    object
#  4   surface_area     239 non-null    float64
#  5   indep_year       192 non-null    float64
#  6   population       239 non-null    int64
#  7   life_expectancy  222 non-null    float64
#  8   gnp              239 non-null    float64
#  9   gnp_old          178 non-null    float64
#  10  local_name       239 non-null    object
#  11  government_form  239 non-null    object
#  12  head_of_state    238 non-null    object
#  13  capital          232 non-null    float64
#  14  code2            239 non-null    object
# dtypes: float64(6), int64(1), object(8)
# memory usage: 28.1+ KB

# %%
df_country_language = pd.read_sql(
"""
select
  *
from
  country_language;
""",
"postgresql://netology:NetoSQL2019@84.201.153.170:19001/world-db"
)

# %%
df_country_language.head()
# Out:
#   country_code    language  is_official  percentage
# 0          AFG      Pashto         True        52.4
# 1          NLD       Dutch         True        95.6
# 2          ANT  Papiamento         True        86.2
# 3          ALB   Albaniana         True        97.9
# 4          DZA      Arabic         True        86.0

# %%
df_country_language.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 984 entries, 0 to 983
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   country_code  984 non-null    object
#  1   language      984 non-null    object
#  2   is_official   984 non-null    bool
#  3   percentage    984 non-null    float64
# dtypes: bool(1), float64(1), object(2)
# memory usage: 24.1+ KB

# %%
df = pd.read_sql(
"""
SELECT 
  *
FROM
  country c
INNER JOIN
  country_language cL
ON
  cL.country_code = c.code
""",
"postgresql://netology:NetoSQL2019@84.201.153.170:19001/world-db"
)
df.head()
# Out:
#   code                  name      continent                     region  \
# 0  AFG           Afghanistan           Asia  Southern and Central Asia
# 1  NLD           Netherlands         Europe             Western Europe
# 2  ANT  Netherlands Antilles  North America                  Caribbean
# 3  ALB               Albania         Europe            Southern Europe
# 4  DZA               Algeria         Africa            Northern Africa
#
#    surface_area  indep_year  population  life_expectancy       gnp   gnp_old  \
# 0      652090.0      1919.0    22720000             45.9    5976.0       NaN
# 1       41526.0      1581.0    15864000             78.3  371362.0  360478.0
# 2         800.0         NaN      217000             74.7    1941.0       NaN
# 3       28748.0      1912.0     3401200             71.6    3205.0    2500.0
# 4     2381740.0      1962.0    31471000             69.7   49982.0   46966.0
#
#               local_name                               government_form  \
# 0  Afganistan/Afqanestan                               Islamic Emirate
# 1              Nederland                       Constitutional Monarchy
# 2   Nederlandse Antillen  Nonmetropolitan Territory of The Netherlands
# 3              Shqipëria                                      Republic
# 4     Al-Jazair/Algérie                                      Republic
#
#           head_of_state  capital code2 country_code    language  is_official  \
# 0         Mohammad Omar      1.0    AF          AFG      Pashto         True
# 1               Beatrix      5.0    NL          NLD       Dutch         True
# 2               Beatrix     33.0    AN          ANT  Papiamento         True
# 3        Rexhep Mejdani     34.0    AL          ALB   Albaniana         True
# 4  Abdelaziz Bouteflika     35.0    DZ          DZA      Arabic         True
#
#    percentage
# 0        52.4
# 1        95.6
# 2        86.2
# 3        97.9
# 4        86.0

# %%
df = pd.read_sql(
"""
SELECT *
FROM country c
INNER JOIN country_language cL
ON cL.country_code = c.code
WHERE is_official = True
""",
"postgresql://netology:NetoSQL2019@84.201.153.170:19001/world-db"
)
df.head()
# Out:
#   code                  name      continent                     region  \
# 0  AFG           Afghanistan           Asia  Southern and Central Asia
# 1  NLD           Netherlands         Europe             Western Europe
# 2  ANT  Netherlands Antilles  North America                  Caribbean
# 3  ALB               Albania         Europe            Southern Europe
# 4  DZA               Algeria         Africa            Northern Africa
#
#    surface_area  indep_year  population  life_expectancy       gnp   gnp_old  \
# 0      652090.0      1919.0    22720000             45.9    5976.0       NaN
# 1       41526.0      1581.0    15864000             78.3  371362.0  360478.0
# 2         800.0         NaN      217000             74.7    1941.0       NaN
# 3       28748.0      1912.0     3401200             71.6    3205.0    2500.0
# 4     2381740.0      1962.0    31471000             69.7   49982.0   46966.0
#
#               local_name                               government_form  \
# 0  Afganistan/Afqanestan                               Islamic Emirate
# 1              Nederland                       Constitutional Monarchy
# 2   Nederlandse Antillen  Nonmetropolitan Territory of The Netherlands
# 3              Shqipëria                                      Republic
# 4     Al-Jazair/Algérie                                      Republic
#
#           head_of_state  capital code2 country_code    language  is_official  \
# 0         Mohammad Omar      1.0    AF          AFG      Pashto         True
# 1               Beatrix      5.0    NL          NLD       Dutch         True
# 2               Beatrix     33.0    AN          ANT  Papiamento         True
# 3        Rexhep Mejdani     34.0    AL          ALB   Albaniana         True
# 4  Abdelaziz Bouteflika     35.0    DZ          DZA      Arabic         True
#
#    percentage
# 0        52.4
# 1        95.6
# 2        86.2
# 3        97.9
# 4        86.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 238 entries, 0 to 237
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   code             238 non-null    object
#  1   name             238 non-null    object
#  2   continent        238 non-null    object
#  3   region           238 non-null    object
#  4   surface_area     238 non-null    float64
#  5   indep_year       197 non-null    float64
#  6   population       238 non-null    int64
#  7   life_expectancy  229 non-null    float64
#  8   gnp              238 non-null    float64
#  9   gnp_old          180 non-null    float64
#  10  local_name       238 non-null    object
#  11  government_form  238 non-null    object
#  12  head_of_state    237 non-null    object
#  13  capital          237 non-null    float64
#  14  code2            238 non-null    object
#  15  country_code     238 non-null    object
#  16  language         238 non-null    object
#  17  is_official      238 non-null    bool
#  18  percentage       238 non-null    float64
# dtypes: bool(1), float64(7), int64(1), object(10)
# memory usage: 33.8+ KB

# %%
df_cl = df_country.merge(
    df_country_language, 
    left_on='code', 
    right_on='country_code', 
    how='inner'
    )
df_cl.head()
# Out:
#   code         name continent                     region  surface_area  \
# 0  AFG  Afghanistan      Asia  Southern and Central Asia      652090.0
# 1  AFG  Afghanistan      Asia  Southern and Central Asia      652090.0
# 2  AFG  Afghanistan      Asia  Southern and Central Asia      652090.0
# 3  AFG  Afghanistan      Asia  Southern and Central Asia      652090.0
# 4  AFG  Afghanistan      Asia  Southern and Central Asia      652090.0
#
#    indep_year  population  life_expectancy     gnp  gnp_old  \
# 0      1919.0    22720000             45.9  5976.0      NaN
# 1      1919.0    22720000             45.9  5976.0      NaN
# 2      1919.0    22720000             45.9  5976.0      NaN
# 3      1919.0    22720000             45.9  5976.0      NaN
# 4      1919.0    22720000             45.9  5976.0      NaN
#
#               local_name  government_form  head_of_state  capital code2  \
# 0  Afganistan/Afqanestan  Islamic Emirate  Mohammad Omar      1.0    AF
# 1  Afganistan/Afqanestan  Islamic Emirate  Mohammad Omar      1.0    AF
# 2  Afganistan/Afqanestan  Islamic Emirate  Mohammad Omar      1.0    AF
# 3  Afganistan/Afqanestan  Islamic Emirate  Mohammad Omar      1.0    AF
# 4  Afganistan/Afqanestan  Islamic Emirate  Mohammad Omar      1.0    AF
#
#   country_code    language  is_official  percentage
# 0          AFG      Pashto         True        52.4
# 1          AFG        Dari         True        32.1
# 2          AFG       Uzbek        False         8.8
# 3          AFG  Turkmenian        False         1.9
# 4          AFG     Balochi        False         0.9

# %%
filter_True = df_cl['is_official'] == True
df_cl.loc[filter_True]
# Out:
#     code                                  name      continent  \
# 0    AFG                           Afghanistan           Asia
# 1    AFG                           Afghanistan           Asia
# 5    NLD                           Netherlands         Europe
# 9    ANT                  Netherlands Antilles  North America
# 11   ANT                  Netherlands Antilles  North America
# ..   ...                                   ...            ...
# 957  EST                               Estonia         Europe
# 962  USA                         United States  North America
# 974  VIR                  Virgin Islands, U.S.  North America
# 979  ZWE                              Zimbabwe         Africa
# 983  UMI  United States Minor Outlying Islands        Oceania
#
#                         region  surface_area  indep_year  population  \
# 0    Southern and Central Asia      652090.0      1919.0    22720000
# 1    Southern and Central Asia      652090.0      1919.0    22720000
# 5               Western Europe       41526.0      1581.0    15864000
# 9                    Caribbean         800.0         NaN      217000
# 11                   Caribbean         800.0         NaN      217000
# ..                         ...           ...         ...         ...
# 957           Baltic Countries       45227.0      1991.0     1439200
# 962              North America     9363520.0      1776.0   278357000
# 974                  Caribbean         347.0         NaN       93000
# 979             Eastern Africa      390757.0      1980.0    11669000
# 983       Micronesia/Caribbean          16.0         NaN           0
#
#      life_expectancy        gnp    gnp_old  \
# 0               45.9     5976.0        NaN
# 1               45.9     5976.0        NaN
# 5               78.3   371362.0   360478.0
# 9               74.7     1941.0        NaN
# 11              74.7     1941.0        NaN
# ..               ...        ...        ...
# 957             69.5     5328.0     3371.0
# 962             77.1  8510700.0  8110900.0
# 974             78.1        0.0        NaN
# 979             37.8     5951.0     8670.0
# 983              NaN        0.0        NaN
#
#                                local_name  \
# 0                   Afganistan/Afqanestan
# 1                   Afganistan/Afqanestan
# 5                               Nederland
# 9                    Nederlandse Antillen
# 11                   Nederlandse Antillen
# ..                                    ...
# 957                                 Eesti
# 962                         United States
# 974   Virgin Islands of the United States
# 979                              Zimbabwe
# 983  United States Minor Outlying Islands
#
#                                   government_form     head_of_state  capital  \
# 0                                 Islamic Emirate     Mohammad Omar      1.0
# 1                                 Islamic Emirate     Mohammad Omar      1.0
# 5                         Constitutional Monarchy           Beatrix      5.0
# 9    Nonmetropolitan Territory of The Netherlands           Beatrix     33.0
# 11   Nonmetropolitan Territory of The Netherlands           Beatrix     33.0
# ..                                            ...               ...      ...
# 957                                      Republic      Lennart Meri   3791.0
# 962                              Federal Republic    George W. Bush   3813.0
# 974                                  US Territory    George W. Bush   4067.0
# 979                                      Republic  Robert G. Mugabe   4068.0
# 983                 Dependent Territory of the US    George W. Bush      NaN
#
#     code2 country_code    language  is_official  percentage
# 0      AF          AFG      Pashto         True        52.4
# 1      AF          AFG        Dari         True        32.1
# 5      NL          NLD       Dutch         True        95.6
# 9      AN          ANT  Papiamento         True        86.2
# 11     AN          ANT       Dutch         True         0.0
# ..    ...          ...         ...          ...         ...
# 957    EE          EST    Estonian         True        65.3
# 962    US          USA     English         True        86.2
# 974    VI          VIR     English         True        81.7
# 979    ZW          ZWE     English         True         2.2
# 983    UM          UMI     English         True         0.0
#
# [238 rows x 19 columns]

# %%
df_True = df_cl[df_cl.is_official == True]

# %%
df_True.head()
# Out:
#    code                  name      continent                     region  \
# 0   AFG           Afghanistan           Asia  Southern and Central Asia
# 1   AFG           Afghanistan           Asia  Southern and Central Asia
# 5   NLD           Netherlands         Europe             Western Europe
# 9   ANT  Netherlands Antilles  North America                  Caribbean
# 11  ANT  Netherlands Antilles  North America                  Caribbean
#
#     surface_area  indep_year  population  life_expectancy       gnp   gnp_old  \
# 0       652090.0      1919.0    22720000             45.9    5976.0       NaN
# 1       652090.0      1919.0    22720000             45.9    5976.0       NaN
# 5        41526.0      1581.0    15864000             78.3  371362.0  360478.0
# 9          800.0         NaN      217000             74.7    1941.0       NaN
# 11         800.0         NaN      217000             74.7    1941.0       NaN
#
#                local_name                               government_form  \
# 0   Afganistan/Afqanestan                               Islamic Emirate
# 1   Afganistan/Afqanestan                               Islamic Emirate
# 5               Nederland                       Constitutional Monarchy
# 9    Nederlandse Antillen  Nonmetropolitan Territory of The Netherlands
# 11   Nederlandse Antillen  Nonmetropolitan Territory of The Netherlands
#
#     head_of_state  capital code2 country_code    language  is_official  \
# 0   Mohammad Omar      1.0    AF          AFG      Pashto         True
# 1   Mohammad Omar      1.0    AF          AFG        Dari         True
# 5         Beatrix      5.0    NL          NLD       Dutch         True
# 9         Beatrix     33.0    AN          ANT  Papiamento         True
# 11        Beatrix     33.0    AN          ANT       Dutch         True
#
#     percentage
# 0         52.4
# 1         32.1
# 5         95.6
# 9         86.2
# 11         0.0

# %%
df_True.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 238 entries, 0 to 983
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   code             238 non-null    object
#  1   name             238 non-null    object
#  2   continent        238 non-null    object
#  3   region           238 non-null    object
#  4   surface_area     238 non-null    float64
#  5   indep_year       197 non-null    float64
#  6   population       238 non-null    int64
#  7   life_expectancy  229 non-null    float64
#  8   gnp              238 non-null    float64
#  9   gnp_old          180 non-null    float64
#  10  local_name       238 non-null    object
#  11  government_form  238 non-null    object
#  12  head_of_state    237 non-null    object
#  13  capital          237 non-null    float64
#  14  code2            238 non-null    object
#  15  country_code     238 non-null    object
#  16  language         238 non-null    object
#  17  is_official      238 non-null    bool
#  18  percentage       238 non-null    float64
# dtypes: bool(1), float64(7), int64(1), object(10)
# memory usage: 35.6+ KB
